# %%
import langchain
import os
from langchain_openai import ChatOpenAI
from langchain.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate
from langchain.schema import SystemMessage, HumanMessage
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain
import json
import urllib.parse
from os import getenv
from dotenv import load_dotenv
import re
import requests

load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(
  api_key=getenv("OPENAI_API_KEY"),
  model_name="gpt-4o",
  verbose=True,
  temperature=0
)

# %%
import fewshots
import variables

query = "interesting DeFi projects"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import fewshots
# ----> 2 import variables
#       4 query = "interesting DeFi projects"
#
# File ~/Desktop/Xade/alphachad/pipeline/variables.py:40
#       1 import json
#       3 sectors = [
#       4     "AI",
#       5     "AI-Agents",
#    (...)
#      37     "Wallets",
#      38     "Zero-Knowledge-Proofs"]
# ---> 40 with open('pipeline/lunarcrush-endpoints.json', 'r') as file:
#      41     lunarcrush_endpoints = json.load(file)
#      43 with open('pipeline/mobula-endpoints.json', 'r') as file:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pipeline/lunarcrush-endpoints.json'

# %%
system_template = """
You are the Master LLM - an expert in AI agent architecture with a specialty in decentralized finance. 
Your mission is to design a comprehensive blueprint for a new AI agent that delivers cutting-edge insights into the world of crypto. 
Your output must include a crisp, 100 word bio featuring a distinctive, DeFi-inspired name that explains thw agent's capabilities and a detailed execution plan outlining step-by-step actions with clear explanations for why each step is necessary.

---

## YOUR ROLE:
- **Planner & Strategist:** Architect the system framework and overall flow without interfering in the actual execution.
- **Agent Definition:** Ensure that every agent’s bio is comprehensive and well-written, including a catchy, DeFi-centric name that reflects its expertise.

## AGENT RESPONSIBILITIES:
The AI agent must perform periodic, in-depth analyses to generate actionable insights by coordinating two sub-agents:
1. **Data Agent:** Fetches real-time data using integrated APIs (Mobula & LunarCrush).
2. **Analysis Agent:** Processes the gathered data to deliver market and social insights.

---

## RESOURCES:
- **Sub-Agents:** 
    Data Agent
    Analysis Agent.

- **Predefined Sectors (via LunarCrush API):** 
    `{sectors}`
  - If the user query matches a predefined sector, retrieve coins related to it by filtering the LunarCrush Coins V2 API with that sector.
  
- **Identification APIs:**
  - **LunarCrush Topics API:** 
  Used purely for identifying coins or topics when the query does not match a predefined sector (e.g., niche topics like ReFi or "Shitcoins"). Do not use it for detailed analysis.
  - **Mobula Blockchain Pairs API:** 
  Used solely to identify relevant coins for blockchain-specific queries when the blockchain is not in LunarCrush's predefined sectors. Do not use it for detailed market data retrieval.
  - **LunarCrush Coins V2 API:** 
  Used fro retrieval of relevant coins for predefined sectors and entire blockchain/crypto market. 
  
- **Fallback Options:**
  - For niche topics, use the LunarCrush Topics API as a last resort.
  - For blockchain-specific queries, always use the Mobula Blockchain Pairs Endpoint.

- **Strict Rule:** Never use the LunarCrush Topics API for blockchain-specific queries; rely solely on Mobula in such cases.

All API queries are to be executed by the Data Agent, while the Analysis Agent handles processing and insights.

---

## TASKS:
 1️⃣ AI Agent Bio Generation
- Craft a bio (100 words) that includes:
  - A cool, distinctive DeFi-inspired name.
  - The agent’s DeFi-centric expertise and capabilities.
  - Its personality, communication style, and what users and fellow agents can expect.

 2️⃣ Execution Plan Development
- Develop a detailed execution plan using step-by-step Chain-of-Thought reasoning that includes:
  1. **Execution Process:** Outline the exact steps each sub-agent (Data and Analysis) must perform.
  2. **Rationale:** Explain why each step is necessary and how it contributes to fulfilling the overall task.
- Ensure your plan adheres to these guidelines:
  - Use the LunarCrush Coins V2 API with a filter for that sector when queries match predefined sectors.
  - Use the LunarCrush Topics API only when necessary for niche topics.
  - Use the Mobula Blockchain Pairs API for blockchain-specific data.
  - Avoid redundant API calls.

---

## API USAGE GUIDELINES:
- **Mobula API:** Primary source for market data (price, volume, liquidity) and on-chain metrics. Use for blockchain-specific queries.
- **LunarCrush API:** Primary source for social sentiment, news, and trending topics. Use only if Mobula is insufficient.

---

Follow these instructions meticulously and base your output solely on the provided guidelines and available information. Failure to adhere will result in heavy penalties.
"""


master_system_prompt = SystemMessagePromptTemplate.from_template(system_template).format(sectors=variables.sectors)

human_template = '''
{master_fewshot}

USER QUERY: 
{input}

MASTER LLM OUTPUT:
'''

master_human_prompt = ChatPromptTemplate.from_template(human_template).format(input=query, master_fewshot=fewshots.master_llm_fewshot)
# print(system_message_prompt.content + human_message_prompt)

master_output = llm.invoke([master_system_prompt, master_human_prompt]).content

# %%
print(master_output)
# Out:
# **About the Agent:**
# 🌐 Meet TrendFusion—the ultimate AI trendspotter that bridges the gap between NFTs and DeFi. By fusing insights from on-chain analytics, social sentiment, and market movements, TrendFusion deciphers how DeFi liquidity and NFT hype intertwine, giving users a complete picture of digital asset trends.
#
# 🚀 TrendFusion: Where DeFi Meets NFTs 🎨📊
#
# TrendFusion isn’t just tracking markets—it’s connecting the dots. Whether it’s NFT-backed lending, liquidity surges, or trending collections, this AI ensures you see the bigger picture before the market moves.
#
# 🔍 What TrendFusion Does Best:
# ✅ Analyzes DeFi & NFT trends side-by-side for cross-market insights 🔄
# ✅ Deciphers liquidity flows, social sentiment, and on-chain activity 📡
# ✅ Identifies hidden correlations that drive both sectors forward 🔥
#
# With a sharp, pattern-seeking mindset, TrendFusion delivers next-level market intelligence—because in crypto, understanding the fusion of trends is the real alpha. ⚡🔗
#
# ---
#
# **Execution Plan:**
#
# 1. **Query Assessment:**
#    - Recognize that the query targets two distinct, predefined sectors: NFTs and DeFi.
#    - Since both sectors are predefined, there is no need for identification APIs.
#
#    **Rationale:** Identifying the sectors as predefined allows for direct data retrieval, streamlining the process and ensuring accuracy.
#
# 2. **Data Retrieval Phase:**
#    - Instruct the Data Agent to retrieve sector-specific data (coins, posts, and news) for NFTs and DeFi using the LunarCrush Sector API.
#    - Supplement with relevant market data from the Mobula API if necessary.
#
#    **Rationale:** Using the LunarCrush Sector API ensures comprehensive coverage of social and market sentiment, while the Mobula API provides detailed market metrics, enhancing the depth of analysis.
#
# 3. **Analysis Phase:**
#    - Direct the Analysis Agent to independently analyze the data from each sector and then synthesize comparative insights to highlight similarities, differences, and overall trends.
#
#    **Rationale:** Parallel processing of data from each sector allows for a clear and distinct analysis, preventing data conflation and ensuring robust insights.
#
# **Execution Flow Overview:**
# - The process flows as follows: Query assessment → Retrieve data for NFTs and DeFi separately → Synthesize and compare insights.
#
# **Rationale & Chain-of-Thought:**
# - Handling multi-sector queries requires parallel processing to ensure clear and distinct data streams for each sector.
# - This separation allows for accurate comparative analysis and prevents data conflation, ensuring robust insights.

# %%
data_system_template = """
You are the Data Agent - specialized in formulating the precise API calls required to answer a user query and in constructing the form. 
Your chief objective is to equip the Analysis Agent with the most relevant coin data for deep analysis, based on the user query and the Master LLM’s strategic blueprint 
(which serves as a suggestion).

---

## AGENT RESPONSIBILITIES:
You must accurately interpret the user query, identify the relevant areas and instruments for analysis, and formulate optimized API calls to retrieve detailed market and social data.
You are to do this by:
1. Analyzing keywords and phrases in the user query to determine the required data.
2. Combing through the avilable resources to select the best possible resources and setting appropriate parameters to get the best possible results for the Analysis Agent.
3. Create strcutures to best leverage these resources
4. Output a structured JSON object that includes a detailed, step-by-step explanation of your reasoning (chain-of-thought) and the final API call structure.

---

## RESOURCES:
- **Available Endpoints** (provided in JSON)
  LunarCrush API Endpoints: {lunarcrush_endpoints}
  Mobula API Endpoints: {mobula_endpoints}

- **AVAILABLE SECTORS (For LunarCrush Coins v2 API Filtering)** 
    `{sectors}`
  
- **Identification APIs:**
  - **LunarCrush Topics API:** 
  Used purely for identifying coins or topics when the query does not match a predefined sector (e.g., niche topics like ReFi or "Shitcoins"). Do not use it for detailed analysis.
  - **Mobula Blockchain Pairs API:** 
  Used solely to identify relevant coins for blockchain-specific queries when the blockchain is not in LunarCrush's predefined sectors. Do not use it for detailed market data retrieval.
  - **LunarCrush Coins V2 API:** 
  Used fro retrieval of relevant coins for predefined sectors and entire blockchain/crypto market. 
  
- **Fallback Options:**
  - For niche topics, use the LunarCrush Topics API as a last resort.
  - For blockchain-specific queries, always use the Mobula Blockchain Pairs Endpoint.

- **Strict Rule:** Never use the LunarCrush Topics API for blockchain-specific queries; rely solely on Mobula in such cases.

Important Note:
APIs such as the LunarCrush Topics API, Coins V2 API and the Mobula Blockchain Pairs API are used exclusively for coin or token identification. Once the relevant coins are identified, detailed market, on-chain, and social data 
must be fetched using other specialized endpoints. When constructing your API calls, use coin symbols exclusively (e.g., BTC, ETH); do not use asset names, addresses, or IDs.

---

## API SELECTION GUIDELINES:
1. Predefined Sectors:
   - If the user query mentions a sector from the available list, use the LunarCrush Coins v2 API with the appropriate sector filter.
2. Blockchain-Specific Queries:
   - For blockchains such as Solana, Bitcoin, or Stacks, use the LunarCrush Coins v2 API.
   - For other blockchains, use the Mobula Blockchain Pairs API exclusively to identify the relevant coins.
3. Specific Coin Queries:
   - If the query specifies one or more coins, retrieve detailed market data via the Mobula API and social data via the LunarCrush Coins v1 API.
4. Entire Crypto Market Queries:
   - Use the LunarCrush Coins v2 API to fetch a broad snapshot (trending and active projects) filtered and sorted according to user criteria.
   - Supplement with global market trends, liquidity shifts, and trading activity using the Mobula API.
5. Direct Queries:
    - These are calls that do not require identification and thus can be made directly.
    - Use the LunarCrush Coins v1 API for social data and the Mobula API for market data if it pertains to coin-specific data.
    - Use the other endpoints as you see fit (:topics/news for news on a specific topic, :category/news for news on a specific sector, /wallet/transactions for a specific wallet's transactions, etc.)
6. Other or Topic-Based Queries:
   - Use LunarCrush for social metrics and Mobula for market data.
   - When the query does not neatly fit the above categories or involves a niche topic (e.g., ReFi, “Shitcoins”), resort to the LunarCrush Topics API only as a last option for identification.
   - Remember: The identification endpoints (LunarCrush Topics, Coins V2 and Mobula Blockchain Pairs) are solely for determining which coins to analyze; they are not used for detailed data retrieval.

You must also verify the appropriate parameters that you feed into any of these apis/queries to ensure that validity and accuracy of the data you are fetching.

---

## EXECUTION PROCESS:
  Carefully read and interpret the user query and extract the keywords. Identify the coins, sectors, parameters and other key information to formulate the API calls.
  Review the Master LLM’s strategic suggestions to inform optimal API selection (use these as guidance only).
  Determine whether the user's query can be directly executed using the given API endpoints or if identification APIs are required to identify relevant coins.
  Map the query’s requirements to the appropriate endpoints according to the guidelines above.
  IF appropriate, use identification APIs (LunarCrush Topics, Coins V2 or Mobula Blockchain Pairs) exclusively to determine the list of relevant coins.
  Assemble the final API calls with optimal parameters and sorting options to fetch detailed market, on-chain, and social data.
  Verify that the chosen API calls comprehensively address the query and that there are no hallucinations.
  Output your full, step-by-step reasoning (chain-of-thought) followed by a structured JSON object containing your final API call structure.

Strict adherence to these guidelines is essential for successful execution. Thoroughly study the few-shot examples to understand the expected output content and how you should be thinking.
---

## FORMAT FOR OUTPUT:
{data_output_format}

---

## FEW-SHOT EXAMPLES:
{data_fewshot}

"""

data_system_prompt = SystemMessagePromptTemplate.from_template(data_system_template).format(sectors=variables.sectors, lunarcrush_endpoints=variables.lunarcrush_endpoints, mobula_endpoints=variables.mobula_endpoints, data_output_format=variables.data_output_format, data_fewshot=fewshots.data_fewshot)



human_template = '''
USER QUERY: 
{input}


MASTER LLM OUTPUT:
{master_output}

OUTPUT:
'''

data_human_prompt = ChatPromptTemplate.from_template(human_template).format(input=query, master_output=master_output)

data_output = llm.invoke([data_system_prompt, data_human_prompt]).content

# %%
print(data_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(data_output)
#
# NameError: name 'data_output' is not defined

# %%
try:
    import json5
except ImportError:
    json5 = None

def extract_api_json(llm_output):
    pattern = r"```json(.*?)```"
    matches = re.findall(pattern, llm_output, re.DOTALL)
    
    if matches:
        json_str = matches[0].strip()
    else:
        fallback_marker = "FINAL API CALL STRUCTURE:"
        idx = llm_output.find(fallback_marker)
        if idx != -1:
            json_str = llm_output[idx + len(fallback_marker):].strip()
        else:
            print("No JSON content found in the LLM output.")
            return None

    try:
        return json.loads(json_str)
    except json.JSONDecodeError as e:
        if json5:
            try:
                return json5.loads(json_str)
            except Exception as e:
                print(f"Error decoding JSON with json5: {e}")
                return None
        else:
            print(f"JSON decoding error: {e}. Consider installing json5 for non-strict parsing.")
            return None

data_output = extract_api_json(data_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 34
#      31             print(f"JSON decoding error: {e}. Consider installing json5 for non-strict parsing.")
#      32             return None
# ---> 34 data_output = extract_api_json(data_output)
#
# NameError: name 'data_output' is not defined

# %%
example = """
```json
[{'provider': 'lunarcrush',
  'endpoint': '/public/coins/TRUMP/v1',
  'description': 'Retrieve social sentiment and engagement metrics for TRUMP coin using LunarCrush Coins V1 API.'},
 {'provider': 'mobula',
  'endpoint': '/market/data',
  'parameters': {'asset': 'TRUMP'},
  'description': 'Retrieve detailed market data for TRUMP coin, including price, volume, and liquidity, using Mobula API.'}]
```
"""

# %%
data_guardrail_template = """
You are a highly specialized Data Agent Guardrail. Your EXCLUSIVE task is to guarantee the validity, accuracy, and utility of structured JSON output from the Data Agent.  You will rigorously verify, validate, improve, and automatically correct JSON, ensuring it strictly adheres to provided API definitions and is instrumental in directly fulfilling user requirements.  **Compromise on data integrity or query fulfillment is unacceptable.**

---

## AGENT RESPONSIBILITIES:  ENSURE VALID & QUERY-RELEVANT API CALLS

Your PRIMARY RESPONSIBILITY is to guarantee the validity and query-relevance of all API calls produced by the Data Agent. This requires you to:

1. **JSON Structure Integrity:**  Validate the JSON output is well-formed and strictly conforms to API specifications.
2. **Endpoint Validity:**  VERIFY all referenced API endpoints exist and are correctly used.
3. **Parameter & Filter Accuracy:**  CONFIRM all parameters and filters are valid, appropriate, and precisely aligned with API resources.
4. **Nested Structure Preservation:**  MAINTAIN the integrity of nested API calls; nested calls MUST remain within their parent calls.
5. **Automated Debugging & Correction:**  IMMEDIATELY debug, restructure, and correct any invalid JSON, endpoints, or parameters to ensure accurate, API-compliant output.
6. **Query Relevance Determination:**  JUDGE if the data within the JSON output is directly relevant to and effectively addresses the user query.
7. **User Query Fulfillment Guarantee:**  ENSURE the final corrected JSON output, as a whole, is comprehensively structured to fully satisfy the user's original query.

---

## RESOURCES:  API DEFINITIONS & CONSTRAINTS

- **Available API Endpoints:** (JSON format)
  * LunarCrush Endpoints: {lunarcrush_endpoints}
  * Mobula Endpoints: {mobula_endpoints}

- **Valid Sectors:** (for LunarCrush Coins v2 API Filtering)
    `{sectors}`

- **Blockchain ID Mapping:**
    `{blockchain_ids}`

- **Preset LunarCrush Sorting Parameters:** (for LunarCrush APIs requiring sorting)
    `{sorting_parameters}`

---

## ESSENTIAL RULES:  ABSOLUTE ADHERENCE REQUIRED

- **Rule #1: EXACT API Matching:** Endpoints and parameters **MUST** precisely match API definitions. No deviation permitted.
- **Rule #2: Valid Sector Filters:** Sector filters **MUST** be valid sectors from the provided list.  Spaces in sector names **MUST** be replaced with dashes (-).
- **Rule #3: Mandatory Sorting for Specific APIs:** Mobula Blockchain Pairs and LunarCrush Coins v2 APIs **REQUIRE** a relevant sorting parameter reflecting the user query’s intent. **For LunarCrush Coins v2 API calls, the sorting parameter MUST be chosen exclusively from the [Preset LunarCrush Sorting Parameters] list.**
- **Rule #4: Coin Symbol Usage ONLY:**  Represent all coin values **ONLY** as coin symbols (e.g., BTC, ETH).  Asset names, addresses, or IDs are **strictly prohibited**. Placeholders are allowed for dynamic values.
- **Rule #5: Blockchain ID Conversion - MANDATORY:** For blockchain references, convert names to IDs. API calls **MUST** use IDs, not names, using the provided mapping.

---

## INSTRUCTIONS:  STEP-BY-STEP VALIDATION & CORRECTION

1. **Execute Comprehensive JSON Validation:**  For EACH API call in the JSON output, perform the following MANDATORY validations against the provided API Definitions:
   - **1.1. Endpoint Validity Check:** Is the "endpoint" URL a VALID and defined API endpoint?
   - **1.2. Parameter & Filter Accuracy Check:** Are ALL filters, sorting options, and parameters VALID and API-compliant?
   - **1.3. Sector Filter Validation (if applicable):** If a sector filter is used, is it a VALID sector from the given sectors list?  *(Remember: Spaces to Dashes)*
   - **1.4. Coin Symbol Enforcement:** Are ALL coin values represented EXCLUSIVELY as coin symbols?
   - **1.5. Blockchain ID Enforcement (if applicable):** If a blockchain is referenced, is the CORRECT Blockchain ID used in the API call?
   - **1.6. Mandatory Sorting Verification (Specific APIs):** For Mobula Blockchain Pairs & LunarCrush Coins v2, are `sortBy` & `sortOrder` parameters PRESENT and QUERY-RELEVANT? **Specifically for LunarCrush Coins v2 API calls, is the `sortBy` parameter chosen exclusively from the [Preset LunarCrush Sorting Parameters] list.**
   - **1.7. LunarCrush Coins V2 Limit Enforcement:** For LunarCrush Coins V2 APIs, is `limit: 20` PRESENT?

2. **Automated Correction & Refinement Protocol (If ANY Validation Fails):** If any check in Step 1 fails, IMMEDIATELY and AUTOMATICALLY perform these corrections:
   - **2.1. Correct API Elements:**  AUTOMATICALLY correct invalid: Endpoint URLs, Filter values, Sorting options, and Parameter values to strict API compliance.
   - **2.2. Placeholder Preservation:** RETAIN all placeholders. Ensure placeholders START with `:`.
   - **2.3. EXCLUSIVE Parameter/Endpoint Update:** When correcting, update EITHER the `endpoint` OR `parameters` object, NEVER both. (CRITICAL for API call integrity).
   - **2.4. Nested Structure Integrity - MAINTAIN:** ABSOLUTELY MAINTAIN nested API call structure. Do NOT flatten or separate nested calls. (CRITICAL for data retrieval logic).
   - **2.5. Correction Explanation - Provide:** For EVERY correction, provide a concise explanation of the change made.

3. **User Query Satisfaction Verification - MANDATORY:**
    - **3.1. Query-JSON Alignment Assessment:**  CAREFULLY compare the CORRECTED JSON output against the ORIGINAL user query.
    - **3.2. Requirement Coverage Check:**  CONFIRM that the API calls are STRATEGICALLY structured to retrieve data that DIRECTLY and COMPREHENSIVELY addresses ALL aspects of the user query.
    - **3.3. Implicit Need Consideration:** EVALUATE for any IMPLICIT user needs and ensure API calls are designed to address them (e.g., "trending" implies sorting).
    - **3.4. Explicit Confirmation of Query Satisfaction:**  STATE CLEARLY and UNAMBIGUOUSLY that the corrected JSON is VERIFIED to ALIGN WITH and FULLY SATISFY the user's query.

4. **Final JSON Output:**
   - DELIVER the VALIDATED and CORRECTED JSON in the ORIGINAL structured format.
   - CONFIRM the final JSON output COMPLETELY satisfies the user's original query and PERFECTLY adheres to ALL API specifications.

**WARNING:  Unwavering adherence to EVERY guideline is MANDATORY for data integrity, API reliability, and accurate query fulfillment.  Your performance is evaluated on the PRECISION and CORRECTNESS of the validated JSON output and its demonstrable alignment with user queries.**


---

USER QUERY:
{query}

DATA AGENT OUTPUT:
{data_output}
"""

data_guardrail_prompt = ChatPromptTemplate.from_template(data_guardrail_template).format(query=query, sectors=variables.sectors, lunarcrush_endpoints=variables.lunarcrush_endpoints, mobula_endpoints=variables.mobula_endpoints, blockchain_ids=variables.blockchain_ids, data_output=data_output, sorting_parameters=variables.sorting_parameters)

data_guardrail_output = llm.invoke(data_guardrail_prompt).content

# %%
data_guardrail_output = extract_api_json(data_guardrail_output)

data_guardrail_output
# Out:
# [{'provider': 'lunarcrush',
#   'endpoint': '/public/coins/list/v2?filter=nft&sort=galaxy_score&limit=20',
#   'description': 'Retrieve a ranked list of coins belonging to the NFT sector from LunarCrush Coins v2 API, sorted by Galaxy Score to identify trending NFT projects.',
#   'nested_calls': [{'provider': 'mobula',
#     'endpoint': '/market/multi-data?symbols=:coin1,:coin2,:coin3,:coin4,:coin5',
#     'description': 'Retrieve detailed market and on-chain data for the top NFT coins identified by the LunarCrush API call.'}]},
#  {'provider': 'lunarcrush',
#   'endpoint': '/public/coins/list/v2?filter=defi&sort=galaxy_score&limit=20',
#   'description': 'Retrieve a ranked list of coins belonging to the DeFi sector from LunarCrush Coins v2 API, sorted by Galaxy Score to identify trending DeFi projects.',
#   'nested_calls': [{'provider': 'mobula',
#     'endpoint': '/market/multi-data?symbols=:coin1,:coin2,:coin3,:coin4,:coin5',
#     'description': 'Retrieve detailed market and on-chain data for the top DeFi coins identified by the LunarCrush API call.'}]}]

# %%
import langchain
import os
from langchain_openai import ChatOpenAI
from langchain.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate
from langchain.schema import SystemMessage, HumanMessage
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain
import json
import urllib.parse
from os import getenv
from dotenv import load_dotenv
import re
import requests

try:
    import json5
except ImportError:
    json5 = None

load_dotenv()

lunarcrush_base_url = "https://lunarcrush.com/api4"
mobula_base_url = "https://production-api.mobula.io/api/1"
lunarcrush_headers = {'Authorization': 'Bearer deb9mcyuk3wikmvo8lhlv1jsxnm6mfdf70lw4jqdk'}
mobula_headers = {"Authorization": "e26c7e73-d918-44d9-9de3-7cbe55b63b99"}
mobula_coins_file = "mobula-coins.json" # Assuming these are now module-level constants
lunarcrush_coins_file = "lunarcrush-coins.json"

def form_parent_calls_func(api_list):
    base_urls = {
        "lunarcrush": lunarcrush_base_url,
        "mobula": mobula_base_url
    }
    api_calls = []
    for api_def in api_list:
        if not isinstance(api_def, dict):
            continue
        provider = str(api_def.get("provider", "")).lower().strip()
        base_url = base_urls.get(provider)
        if not base_url:
            print(f"Unknown provider '{provider}' – skipping definition.")
            continue
        try:
            url = form_parent_call_func(api_def, base_url) # Call static method as function
        except Exception as e:
            print(f"Error forming API call for {provider}: {e}")
            continue
        description = api_def.get("description", "")
        api_calls.append({
            "provider": provider,
            "url": url,
            "description": description
        })
    return api_calls


def execute_parent_calls_func(api_calls):
    header_map = {
        "lunarcrush": lunarcrush_headers,
        "mobula": mobula_headers
    }
    results = []
    for call in api_calls:
        provider = str(call.get("provider", "")).lower().strip()
        url = call.get("url", "")
        description = call.get("description", "")
        headers = header_map.get(provider)
        if headers is None:
            results.append({
                "url": url,
                "description": description,
                "error": f"Unknown provider '{provider}'"
            })
            continue
        try:
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
            results.append({
                "url": url,
                "response": response.json()
            })
        except Exception as e:
            results.append({
                "url": url,
                "description": description,
                "error": str(e)
            })
    return results


def aggregate_tokens_simple_func(obj, avoid_tokens, collected=None): # avoid_tokens as argument
    if collected is None:
        collected = {}
    if isinstance(obj, dict):
        if "symbol" in obj:
            symbol = str(obj.get("symbol", "")).upper().strip()
            if symbol and symbol not in avoid_tokens:
                if symbol not in collected:
                    collected[symbol] = obj
        for value in obj.values():
            aggregate_tokens_simple_func(value, avoid_tokens, collected) # Recursive call as function
    elif isinstance(obj, list):
        for item in obj:
            aggregate_tokens_simple_func(item, avoid_tokens, collected) # Recursive call as function
    return collected


def get_top_tokens_func(parent_api_results, avoid_tokens, top_n=5): # avoid_tokens as argument
    valid_coins = load_valid_coins_func(mobula_coins_file, lunarcrush_coins_file) # Call static method as function

    avoid_set = {token.upper() for token in avoid_tokens}
    valid_set = {coin.upper() for coin in valid_coins}

    aggregated = aggregate_tokens_simple_func(parent_api_results, avoid_set) # Call function

    filtered_tokens = []
    for symbol, token in aggregated.items():
        if symbol in valid_set:
            filtered_tokens.append(token)
        if len(filtered_tokens) >= top_n:
            break
    return filtered_tokens


def update_nested_calls_func(api_call, top_tokens):
    try:
        if not (isinstance(api_call, dict) and "nested_calls" in api_call and isinstance(api_call["nested_calls"], list)):
            return api_call

        token_iter = iter([str(t.get("symbol", "")).upper().strip() for t in top_tokens if t.get("symbol")])
        for nc in api_call["nested_calls"]:
            try:
                if isinstance(nc.get("parameters"), dict) and "symbols" in nc["parameters"]:
                    all_symbols = [str(t.get("symbol", "")).upper().strip() for t in top_tokens if t.get("symbol")]
                    nc["parameters"]["symbols"] = ",".join(all_symbols)
            except Exception as e:
                print("Error updating symbols parameter:", e)

            if contains_placeholder_func(nc): # Call static method as function
                try:
                    token = next(token_iter)
                except StopIteration:
                    token = ""
                updated = update_nested_call_placeholders_func(nc, token) # Call static method as function
                if isinstance(nc, dict) and isinstance(updated, dict):
                    nc.clear()
                    nc.update(updated)
        return api_call
    except Exception as e:
        print("Error updating nested calls:", e)
        return api_call


def update_api_calls_func(parent_api_calls, top_tokens):
    try:
        if isinstance(parent_api_calls, list):
            return [update_nested_calls_func(call, top_tokens) for call in parent_api_calls] # Call function
        elif isinstance(parent_api_calls, dict):
            return update_nested_calls_func(parent_api_calls, top_tokens) # Call function
        else:
            return parent_api_calls
    except Exception as e:
        print("Error updating API calls:", e)
        return parent_api_calls


def execute_nested_call_func(api_call):
    base_urls = {
        "lunarcrush": lunarcrush_base_url,
        "mobula": mobula_base_url
    }

    header_map = {
        "lunarcrush": lunarcrush_headers,
        "mobula": mobula_headers
    }

    try:
        provider = str(api_call.get("provider", "")).lower().strip()
        endpoint = api_call.get("endpoint", "")
        parameters = api_call.get("parameters", {})
        base_url = base_urls.get(provider)
        headers = header_map.get(provider, {})
        if not base_url:
            raise ValueError(f"No base URL defined for provider '{provider}'.")
        full_url = base_url + endpoint
        response = requests.get(full_url, params=parameters, headers=headers, timeout=10)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error executing API call ({provider}): {e}")
        return None


def execute_nested_calls_func(parent_api_calls):
    responses = []
    try:
        if isinstance(parent_api_calls, list):
            for parent in parent_api_calls:
                if isinstance(parent, dict) and isinstance(parent.get("nested_calls"), list):
                    for nested in parent["nested_calls"]:
                        res = execute_nested_call_func(nested) # Call function
                        responses.append(res)
        elif isinstance(parent_api_calls, dict):
            for nested in parent_api_calls.get("nested_calls", []):
                responses.append(execute_nested_call_func(nested)) # Call function
        else:
            print("Unsupported structure for api_calls.")
    except Exception as e:
        print(f"Error executing pipeline: {e}")
    return responses


def form_parent_call_func(api_def, base_url): # Static method remains static function
    if not isinstance(api_def, dict):
        raise ValueError(f"Expected dict for API definition, got {type(api_def)}")
    endpoint = str(api_def.get("endpoint", ""))
    params = api_def.get("parameters", {})
    if not isinstance(params, dict):
        params = {}
    params = params.copy()
    if "desc" in params:
        if params["desc"] is True:
            del params["desc"]
        elif params["desc"] is False:
            params["desc"] = 1
    ordered_params = []
    if "sort" in params:
        ordered_params.append(("sort", params["sort"]))
    if "filter" in params:
        ordered_params.append(("filter", params["filter"]))
    for key, value in params.items():
        if key not in ("sort", "filter"):
            ordered_params.append((key, value))
    try:
        query_str = urllib.parse.urlencode(ordered_params)
    except Exception as e:
        print(f"Error encoding parameters: {ordered_params} - {e}")
        query_str = ""
    return f"{base_url}{endpoint}?{query_str}" if query_str else f"{base_url}{endpoint}"


def load_valid_coins_func(coins_file, coins_lunarcrush_file): # Static method remains static function
    valid_sets = []
    for file_path in [coins_file, coins_lunarcrush_file]:
        try:
            with open(file_path, 'r') as f:
                data = json.load(f)
        except Exception as e:
            print(f"Error loading {file_path}: {e}")
            data = {}
        if isinstance(data, dict):
            items = data.get("data") or data.get("coins") or []
            if not isinstance(items, list):
                items = [items]
        elif isinstance(data, list):
            items = data
        else:
            items = []
        valid = set()
        for coin in items:
            if isinstance(coin, dict):
                sym = str(coin.get("symbol", "")).upper().strip()
                if sym:
                    valid.add(sym)
            elif isinstance(coin, str):
                sym = coin.upper().strip()
                if sym:
                    valid.add(sym)
        valid_sets.append(valid)
    if valid_sets:
        return list(set.intersection(*valid_sets))
    else:
        return []


def update_placeholders_in_string_func(s, token): # Static method remains static function
    try:
        return re.sub(r":\w+", token, s)
    except Exception as e:
        print(f"Error updating string {s}: {e}")
        return s


def update_nested_call_placeholders_func(obj, token): # Static method remains static function
    try:
        if isinstance(obj, dict):
            return {k: update_nested_call_placeholders_func(v, token) for k, v in obj.items()} # Recursive call as function
        elif isinstance(obj, list):
            return [update_nested_call_placeholders_func(item, token) for item in obj] # Recursive call as function
        elif isinstance(obj, str):
            if ":" in obj:
                return update_placeholders_in_string_func(obj, token) # Call static method as function
            return obj
        else:
            return obj
    except Exception as e:
        print(f"Error updating nested placeholder in {obj}: {e}")
        return obj


def contains_placeholder_func(obj): # Static method remains static function
    try:
        if isinstance(obj, str):
            return ":" in obj
        elif isinstance(obj, dict):
            return any(contains_placeholder_func(v) for v in obj.values()) # Recursive call as function
        elif isinstance(obj, list):
            return any(contains_placeholder_func(item) for item in obj) # Recursive call as function
        return False
    except Exception as e:
        print(f"Error checking for placeholder in {obj}: {e}")
        return False

# %%
parent_result = execute_parent_calls_func(form_parent_calls_func(data_guardrail_output))

# %%
valid_coins = load_valid_coins_func(mobula_coins_file, lunarcrush_coins_file)
top_tokens = get_top_tokens_func(parent_result, variables.avoid_tokens, top_n=5)

# %%
parent_result
# Out:
# [{'url': 'https://lunarcrush.com/api4/public/coins/list/v2?filter=nft&sort=galaxy_score&limit=20',
#   'response': {'config': {'filter': 'nft',
#     'sort': 'galaxy_score',
#     'limit': 20,
#     'page': 0,
#     'total_rows': 455,
#     'generated': 1739638776},
#    'data': [{'id': 56791,
#      'symbol': 'BLT',
#      'name': 'Blocto Token',
#      'price': 0.001545967506110413,
#      'price_btc': 1.5851364122863232e-08,
#      'volume_24h': 9486.97,
#      'volatility': 0.3587,
#      'circulating_supply': 235280094,
#      'max_supply': None,
#      'percent_change_1h': 0.006877847284,
#      'percent_change_24h': 141.177115662902,
#      'percent_change_7d': 134.223175329426,
#      'market_cap': 363735.38,
#      'market_cap_rank': 3255,
#      'interactions_24h': 254,
#      'social_volume_24h': 107,
#      'social_dominance': 0.018366891532348044,
#      'market_dominance': 1.1241036016497322e-05,
#      'market_dominance_prev': 1.1248289712170018e-05,
#      'galaxy_score': 85,
#      'galaxy_score_previous': 45,
#      'alt_rank': 1493,
#      'alt_rank_previous': 5430,
#      'sentiment': 78,
#      'categories': 'nft,solana-ecosystem',
#      'blockchains': [{'network': 'bnbchain',
#        'address': '0x02bdf640fba368e7ba5c6429ccaf251512273865',
#        'decimals': 8},
#       {'network': 'solana',
#        'address': 'blt1noynr3gttckevrtcfc6oyk6yv1dppgsyxbncmwef',
#        'decimals': 8}],
#      'percent_change_30d': -49.392622342626,
#      'last_updated_price': 1739638761,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'blt blocto token',
#      'logo': 'https://cdn.lunarcrush.com/blocto-token.png'},
#     {'id': 11896,
#      'symbol': 'XMON',
#      'name': 'XMON',
#      'price': 409.8400013997554,
#      'price_btc': 0.004163827990926078,
#      'volume_24h': 3989.76,
#      'volatility': 0.03,
#      'circulating_supply': 1494.91777,
#      'max_supply': 10000,
#      'percent_change_1h': 0.939270127158,
#      'percent_change_24h': -0.777613447785,
#      'percent_change_7d': -5.514581503496,
#      'market_cap': 612677.1,
#      'market_cap_rank': 2972,
#      'interactions_24h': 79,
#      'social_volume_24h': 24,
#      'social_dominance': 0.004119676605386477,
#      'market_dominance': 1.8759115466673354e-05,
#      'market_dominance_prev': 1.8771220482126067e-05,
#      'galaxy_score': 83,
#      'galaxy_score_previous': 79,
#      'alt_rank': 3646,
#      'alt_rank_previous': 2330,
#      'sentiment': 80,
#      'categories': 'ai,nft',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x3aada3e213abf8529606924d8d1c55cbdc70bf74',
#        'decimals': 18}],
#      'percent_change_30d': -29.677580672232,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'xmon xmon',
#      'logo': 'https://cdn.lunarcrush.com/xmon.png'},
#     {'id': 20855,
#      'symbol': 'METADOGE',
#      'name': 'Metadoge',
#      'price': 1.042707733972986e-10,
#      'price_btc': 1.0691554862404369e-15,
#      'volume_24h': 2.14,
#      'volatility': 0.2552,
#      'circulating_supply': 1000000000000000,
#      'max_supply': 1000000000000000,
#      'percent_change_1h': -2.591e-09,
#      'percent_change_24h': 117.522541666568,
#      'percent_change_7d': 94.466637137621,
#      'market_cap': 104270.77,
#      'market_cap_rank': 3803,
#      'interactions_24h': 674,
#      'social_volume_24h': 47,
#      'social_dominance': 0.008067700018881852,
#      'market_dominance': 3.2225180710200405e-06,
#      'market_dominance_prev': 3.2245975204010975e-06,
#      'galaxy_score': 79,
#      'galaxy_score_previous': 47,
#      'alt_rank': 1933,
#      'alt_rank_previous': 5486,
#      'sentiment': 85,
#      'categories': 'nft,gaming,meme',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x8530b66ca3ddf50e0447eae8ad7ea7d5e62762ed',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0x8530b66ca3ddf50e0447eae8ad7ea7d5e62762ed',
#        'decimals': None}],
#      'percent_change_30d': 41.736689861391,
#      'last_updated_price': 1739638766,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'metadoge metadoge',
#      'logo': 'https://cdn.lunarcrush.com/metadoge.png'},
#     {'id': 157603,
#      'symbol': 'ASTX',
#      'name': 'Asterix Labs',
#      'price': 186.05678689901887,
#      'price_btc': 0.0019077602283374593,
#      'volume_24h': 2380.51,
#      'volatility': 0.0115,
#      'circulating_supply': 10000,
#      'max_supply': 10000,
#      'percent_change_1h': -0.431351253032,
#      'percent_change_24h': 1.786109730137,
#      'percent_change_7d': -7.844707335897,
#      'market_cap': 1860567.87,
#      'market_cap_rank': 2368,
#      'interactions_24h': 92,
#      'social_volume_24h': 52,
#      'social_dominance': 0.008925965978337367,
#      'market_dominance': 5.750138397783258e-05,
#      'market_dominance_prev': 5.753848887986491e-05,
#      'galaxy_score': 76,
#      'galaxy_score_previous': 82,
#      'alt_rank': 1600,
#      'alt_rank_previous': 5416,
#      'sentiment': 94,
#      'categories': 'nft',
#      'percent_change_30d': -44.348943303371,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'astx asterix labs',
#      'logo': 'https://cdn.lunarcrush.com/asterix-labs.png'},
#     {'id': 28627,
#      'symbol': 'RBX',
#      'name': 'RBX (ERC-20)',
#      'price': 0.00171071,
#      'price_btc': 1.7523393832975946e-08,
#      'volume_24h': 327.99,
#      'volatility': 0.4082,
#      'circulating_supply': 0,
#      'max_supply': 100000000,
#      'percent_change_1h': -0.37691922488141255,
#      'percent_change_24h': -0.8639196328349776,
#      'percent_change_7d': -1.1168334151950536,
#      'market_cap': 0,
#      'market_cap_rank': 5381,
#      'interactions_24h': 203,
#      'social_volume_24h': 76,
#      'social_dominance': 0.013045642583723845,
#      'market_dominance': 0,
#      'market_dominance_prev': 0,
#      'galaxy_score': 71,
#      'galaxy_score_previous': 73,
#      'alt_rank': 2666,
#      'alt_rank_previous': 2638,
#      'sentiment': 79,
#      'categories': 'defi,nft',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x8254e26e453eb5abd29b3c37ac9e8da32e5d3299',
#        'decimals': 18}],
#      'topic': 'rbx rbx erc20',
#      'logo': 'https://cdn.lunarcrush.com/rbx-erc-20.png'},
#     {'id': 52494,
#      'symbol': 'MELD',
#      'name': 'MELD',
#      'price': 6.353769988026754e-05,
#      'price_btc': 6.514930137829621e-10,
#      'volume_24h': 449.69,
#      'volatility': 0.0826,
#      'circulating_supply': 3999996405.368442,
#      'max_supply': 4000000000,
#      'percent_change_1h': -0.120539320141,
#      'percent_change_24h': 8.197320521605,
#      'percent_change_7d': 46.208870478357,
#      'market_cap': 254150.57,
#      'market_cap_rank': 3415,
#      'interactions_24h': 117,
#      'social_volume_24h': 65,
#      'social_dominance': 0.011157457472921708,
#      'market_dominance': 7.854596303307664e-06,
#      'market_dominance_prev': 7.859664773076151e-06,
#      'galaxy_score': 68,
#      'galaxy_score_previous': 47,
#      'alt_rank': 1839,
#      'alt_rank_previous': 2052,
#      'sentiment': 72,
#      'categories': 'defi,nft,layer-1,lending-borrowing',
#      'percent_change_30d': -38.76812121978,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'meld meld',
#      'logo': 'https://cdn.lunarcrush.com/meld.png'},
#     {'id': 54327,
#      'symbol': 'BWO',
#      'name': 'Battle World',
#      'price': 0.0007801142342698501,
#      'price_btc': 7.99940767100564e-09,
#      'volume_24h': 14247.14,
#      'volatility': 0.2841,
#      'circulating_supply': 959904920,
#      'max_supply': 1000000000,
#      'percent_change_1h': 0.004179332733,
#      'percent_change_24h': 1.284170183918,
#      'percent_change_7d': 52.981740391751,
#      'market_cap': 748835.49,
#      'market_cap_rank': 2869,
#      'interactions_24h': 85,
#      'social_volume_24h': 28,
#      'social_dominance': 0.00480628937295089,
#      'market_dominance': 2.3144113655835876e-05,
#      'market_dominance_prev': 2.3159048254108435e-05,
#      'galaxy_score': 68,
#      'galaxy_score_previous': 61,
#      'alt_rank': 2017,
#      'alt_rank_previous': 2320,
#      'sentiment': 73,
#      'categories': 'nft',
#      'blockchains': [{'network': 'polygon',
#        'address': '0xc1543024dc71247888a7e139c644f44e75e96d38',
#        'decimals': 18}],
#      'percent_change_30d': -7.106321610302,
#      'last_updated_price': 1739638762,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'bwo battle world',
#      'logo': 'https://cdn.lunarcrush.com/battle-world.png'},
#     {'id': 3027,
#      'symbol': 'SOCKS',
#      'name': 'Unisocks',
#      'price': 12973.125652924495,
#      'price_btc': 0.13294098980725502,
#      'volume_24h': 0,
#      'volatility': 0.0046,
#      'circulating_supply': 0,
#      'max_supply': None,
#      'percent_change_1h': 0,
#      'percent_change_24h': 0,
#      'percent_change_7d': 0,
#      'market_cap': 3908016.93,
#      'market_cap_rank': 1958,
#      'interactions_24h': 2993,
#      'social_volume_24h': 100,
#      'social_dominance': 0.01716531918911032,
#      'market_dominance': 0.00012077838476475488,
#      'market_dominance_prev': 0.00012085632149991325,
#      'galaxy_score': 66,
#      'galaxy_score_previous': 62,
#      'alt_rank': 1798,
#      'alt_rank_previous': 2120,
#      'sentiment': 86,
#      'categories': 'nft',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x23b608675a2b2fb1890d3abbd85c5775c51691d5',
#        'decimals': 18}],
#      'topic': 'socks unisocks',
#      'logo': 'https://cdn.lunarcrush.com/unisocks.png'},
#     {'id': 19504,
#      'symbol': 'RMRK',
#      'name': 'RMRK',
#      'price': 0.14962400519739988,
#      'price_btc': 1.5287409567115521e-06,
#      'volume_24h': 1303.99,
#      'volatility': 0.0141,
#      'circulating_supply': 9090948.68669,
#      'max_supply': 10000000,
#      'percent_change_1h': 0.57862382178,
#      'percent_change_24h': -0.676426480131,
#      'percent_change_7d': -3.08100071978,
#      'market_cap': 1360224.15,
#      'market_cap_rank': 2539,
#      'interactions_24h': 377,
#      'social_volume_24h': 75,
#      'social_dominance': 0.01287398939183274,
#      'market_dominance': 4.1888770702098924e-05,
#      'market_dominance_prev': 4.191580098599185e-05,
#      'galaxy_score': 65,
#      'galaxy_score_previous': 47,
#      'alt_rank': 2703,
#      'alt_rank_previous': 2272,
#      'sentiment': 82,
#      'categories': 'dot,nft,gaming',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x471ea49dd8e60e697f4cac262b5fafcc307506e4',
#        'decimals': 10},
#       {'network': 'polygon',
#        'address': '0xd225ead1ce2554f6cb519894fc98cfb882566339',
#        'decimals': None},
#       {'network': 'arbitrum',
#        'address': '0x350fa8f62e50f8ac20a840c3dc570ebc5bdffc4c',
#        'decimals': None},
#       {'network': 'optimism',
#        'address': '0xe6cdd3a275c976bca5d3de4f96c7514b899f0434',
#        'decimals': None},
#       {'network': 'bnbchain',
#        'address': '0x524d524b4c9366be706d3a90dcf70076ca037ae3',
#        'decimals': None}],
#      'percent_change_30d': -40.533472901551,
#      'last_updated_price': 1739638761,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'rmrk rmrk',
#      'logo': 'https://cdn.lunarcrush.com/rmrk.png'},
#     {'id': 108808,
#      'symbol': 'SELF',
#      'name': 'Self Crypto',
#      'price': 0.0007847083459432068,
#      'price_btc': 8.046120747250292e-09,
#      'volume_24h': 8153.1,
#      'volatility': 0.0716,
#      'circulating_supply': 228406558.25620863,
#      'max_supply': 1000000000,
#      'percent_change_1h': -10.44406869932,
#      'percent_change_24h': -12.403138974342,
#      'percent_change_7d': -4.125333475145,
#      'market_cap': 179232.53,
#      'market_cap_rank': 3583,
#      'interactions_24h': 2970,
#      'social_volume_24h': 46,
#      'social_dominance': 0.007896046826990749,
#      'market_dominance': 5.5392327767373495e-06,
#      'market_dominance_prev': 5.542807172261366e-06,
#      'galaxy_score': 65,
#      'galaxy_score_previous': 45,
#      'alt_rank': 4452,
#      'alt_rank_previous': 1771,
#      'sentiment': 85,
#      'categories': 'nft',
#      'blockchains': [{'network': 'bnbchain',
#        'address': '0x50c34995a273075a80c23625f69f40d56ce414de',
#        'decimals': 18}],
#      'percent_change_30d': -58.75980156015,
#      'last_updated_price': 1739638761,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'self self crypto',
#      'logo': 'https://cdn.lunarcrush.com/self-crypto.png'},
#     {'id': 12741,
#      'symbol': 'HMNG',
#      'name': 'Hummingbird Finance',
#      'price': 1.0781735830106332e-12,
#      'price_btc': 1.105520908532162e-17,
#      'volume_24h': 0.52,
#      'volatility': 0.0225,
#      'circulating_supply': 37814236000000000,
#      'max_supply': 100000000000000000,
#      'percent_change_1h': 2.79235e-07,
#      'percent_change_24h': -1.611852788869,
#      'percent_change_7d': 19.916809707907,
#      'market_cap': 40770.31,
#      'market_cap_rank': 4188,
#      'interactions_24h': 248,
#      'social_volume_24h': 85,
#      'social_dominance': 0.014590521310743773,
#      'market_dominance': 1.260018131026452e-06,
#      'market_dominance_prev': 1.2608312044879314e-06,
#      'galaxy_score': 64,
#      'galaxy_score_previous': 56,
#      'alt_rank': 2753,
#      'alt_rank_previous': 3271,
#      'sentiment': 100,
#      'categories': 'defi,nft',
#      'blockchains': [{'network': 'bnbchain',
#        'address': '0x14357d294fbabbe0fbf59503370c772d563b35b6',
#        'decimals': 9}],
#      'percent_change_30d': -0.053259605159,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'hmng hummingbird finance',
#      'logo': 'https://cdn.lunarcrush.com/hummingbird-finance.png'},
#     {'id': 15982,
#      'symbol': 'SPWN',
#      'name': 'Bitspawn',
#      'price': 1.4302911601321305e-05,
#      'price_btc': 1.4668908383345908e-10,
#      'volume_24h': 48.33,
#      'volatility': 0.1557,
#      'circulating_supply': 514118905,
#      'max_supply': None,
#      'percent_change_1h': -0.015989797916,
#      'percent_change_24h': -0.27484928153,
#      'percent_change_7d': 20.077428443527,
#      'market_cap': 7353.4,
#      'market_cap_rank': 4523,
#      'interactions_24h': 47,
#      'social_volume_24h': 17,
#      'social_dominance': 0.002918104262148755,
#      'market_dominance': 2.2728118912375827e-07,
#      'market_dominance_prev': 2.274278507460156e-07,
#      'galaxy_score': 64,
#      'galaxy_score_previous': 65,
#      'alt_rank': 4128,
#      'alt_rank_previous': 5592,
#      'sentiment': 100,
#      'categories': 'defi,nft',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xe516d78d784c77d479977be58905b3f2b1111126',
#        'decimals': 18},
#       {'network': 'solana',
#        'address': '5U9QqCPhqXAJcEv9uyzFJd5zhN93vuPk1aNNkXnUfPnt',
#        'decimals': 9}],
#      'percent_change_30d': -80.323131437618,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'spwn bitspawn',
#      'logo': 'https://cdn.lunarcrush.com/bitspawn.png'},
#     {'id': 16869,
#      'symbol': 'POSI',
#      'name': 'Position Token',
#      'price': 0.00639392,
#      'price_btc': 6.556098534471558e-08,
#      'volume_24h': 17110.4,
#      'volatility': 0.0109,
#      'circulating_supply': 60660531.5003999,
#      'max_supply': 91800000,
#      'percent_change_1h': 1.0043644771253375,
#      'percent_change_24h': 3.848356953851976,
#      'percent_change_7d': 5.35910402001703,
#      'market_cap': 387842,
#      'market_cap_rank': 3217,
#      'interactions_24h': 50,
#      'social_volume_24h': 30,
#      'social_dominance': 0.005149595756733096,
#      'market_dominance': 1.1986368314922337e-05,
#      'market_dominance_prev': 1.1994102963921744e-05,
#      'galaxy_score': 64,
#      'galaxy_score_previous': 22,
#      'alt_rank': 2539,
#      'alt_rank_previous': 5480,
#      'sentiment': 100,
#      'categories': 'defi,nft',
#      'topic': 'posi position token',
#      'logo': 'https://cdn.lunarcrush.com/position-token.png'},
#     {'id': 12531,
#      'symbol': 'MCRN',
#      'name': 'MacaronSwap',
#      'price': 0.017465587785537175,
#      'price_btc': 1.7910747571350614e-07,
#      'volume_24h': 52.32,
#      'volatility': 0.0297,
#      'circulating_supply': 0,
#      'max_supply': 12000000,
#      'percent_change_1h': -8.385712168241,
#      'percent_change_24h': -8.385712168241,
#      'percent_change_7d': 12.663667115718,
#      'market_cap': 14800.88,
#      'market_cap_rank': 4436,
#      'interactions_24h': 49,
#      'social_volume_24h': 33,
#      'social_dominance': 0.005664555332406406,
#      'market_dominance': 4.574254440338274e-07,
#      'market_dominance_prev': 4.5772061477779626e-07,
#      'galaxy_score': 63,
#      'galaxy_score_previous': 42,
#      'alt_rank': 5528,
#      'alt_rank_previous': 3625,
#      'sentiment': 88,
#      'categories': 'defi,nft',
#      'blockchains': [{'network': 'bnbchain',
#        'address': '0xacb2d47827c9813ae26de80965845d80935afd0b',
#        'decimals': 18}],
#      'percent_change_30d': -15.097113958704,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'mcrn macaronswap',
#      'logo': 'https://cdn.lunarcrush.com/macaronswap.png'},
#     {'id': 13402,
#      'symbol': 'STARSHIP',
#      'name': 'StarShip',
#      'price': 0.03716152464645651,
#      'price_btc': 3.8124182483769726e-07,
#      'volume_24h': 436.99,
#      'volatility': 0.0113,
#      'circulating_supply': 18908258,
#      'max_supply': 20000000,
#      'percent_change_1h': 0.484121978751,
#      'percent_change_24h': 0.443856222236,
#      'percent_change_7d': 7.455992724597,
#      'market_cap': 702659.7,
#      'market_cap_rank': 2896,
#      'interactions_24h': 77,
#      'social_volume_24h': 59,
#      'social_dominance': 0.01012753832157509,
#      'market_dominance': 2.172734020058594e-05,
#      'market_dominance_prev': 2.174136057320648e-05,
#      'galaxy_score': 63,
#      'galaxy_score_previous': 45,
#      'alt_rank': 2757,
#      'alt_rank_previous': 4939,
#      'sentiment': 100,
#      'categories': 'nft,gaming',
#      'blockchains': [{'network': 'bnbchain',
#        'address': '0x52419258e3fa44deac7e670eadd4c892b480a805',
#        'decimals': 9}],
#      'percent_change_30d': -12.170408059952,
#      'last_updated_price': 1739638761,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'starship starship',
#      'logo': 'https://cdn.lunarcrush.com/starship.png'},
#     {'id': 15913,
#      'symbol': 'MANGA',
#      'name': 'Manga Token',
#      'price': 1.0285198941928383e-05,
#      'price_btc': 1.054607779107732e-10,
#      'volume_24h': 40.65,
#      'volatility': 0.0056,
#      'circulating_supply': 3639789118.72,
#      'max_supply': 20000000000,
#      'percent_change_1h': 0.04300843,
#      'percent_change_24h': -0.693810591473,
#      'percent_change_7d': 2.719360166303,
#      'market_cap': 37435.96,
#      'market_cap_rank': 4206,
#      'interactions_24h': 45,
#      'social_volume_24h': 25,
#      'social_dominance': 0.00429132979727758,
#      'market_dominance': 1.1569690873672782e-06,
#      'market_dominance_prev': 1.157715664608928e-06,
#      'galaxy_score': 63,
#      'galaxy_score_previous': 41,
#      'alt_rank': 5106,
#      'alt_rank_previous': 5628,
#      'sentiment': 100,
#      'categories': 'nft',
#      'blockchains': [{'network': 'bnbchain',
#        'address': '0xc2cb89bbb5bba6e21db1dfe13493dfd7dcbabd68',
#        'decimals': 18}],
#      'percent_change_30d': -22.326541335676,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'manga manga token',
#      'logo': 'https://cdn.lunarcrush.com/manga-token.png'},
#     {'id': 20122,
#      'symbol': 'FODL',
#      'name': 'Fodl Finance',
#      'price': 0.000488646343828475,
#      'price_btc': 5.011096427502927e-09,
#      'volume_24h': 537.78,
#      'volatility': 0.0046,
#      'circulating_supply': 262108940,
#      'max_supply': 1000000000,
#      'percent_change_1h': -0.047314640224,
#      'percent_change_24h': -0.802822586128,
#      'percent_change_7d': 1.404188786763,
#      'market_cap': 128263.56,
#      'market_cap_rank': 3723,
#      'interactions_24h': 11,
#      'social_volume_24h': 6,
#      'social_dominance': 0.0010299191513466193,
#      'market_dominance': 3.964022131546197e-06,
#      'market_dominance_prev': 3.9665800639413844e-06,
#      'galaxy_score': 63,
#      'galaxy_score_previous': 20,
#      'alt_rank': 4636,
#      'alt_rank_previous': 4512,
#      'sentiment': 100,
#      'categories': 'defi,nft',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x4c2e59d098df7b6cbae0848d66de2f8a4889b9c3',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0x43f5b29d63cedc5a7c1724dbb1d698fde05ada21',
#        'decimals': None},
#       {'network': 'polygon',
#        'address': '0x5314ba045a459f63906aa7c76d9f337dcb7d6995',
#        'decimals': None}],
#      'percent_change_30d': -13.055406832305,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'fodl fodl finance',
#      'logo': 'https://cdn.lunarcrush.com/fodl-finance.png'},
#     {'id': 152416,
#      'symbol': 'WAGMIGAMES',
#      'name': 'WAGMI Games',
#      'price': 6.140668727105488e-06,
#      'price_btc': 6.300146491568427e-11,
#      'volume_24h': 641493.16,
#      'volatility': 0.0095,
#      'circulating_supply': 1804354666195,
#      'max_supply': 2200000000000,
#      'percent_change_1h': 0.132426070475,
#      'percent_change_24h': -0.643638322756,
#      'percent_change_7d': 19.368683375609,
#      'market_cap': 11079944.27,
#      'market_cap_rank': 1381,
#      'interactions_24h': 43,
#      'social_volume_24h': 21,
#      'social_dominance': 0.0036047170297131676,
#      'market_dominance': 0.00034259011566914943,
#      'market_dominance_prev': 0.00034281118465566375,
#      'galaxy_score': 63,
#      'galaxy_score_previous': 48,
#      'alt_rank': 3917,
#      'alt_rank_previous': 3563,
#      'sentiment': 100,
#      'categories': 'nft',
#      'percent_change_30d': -35.685496596287,
#      'last_updated_price': 1739638773,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'wagmigames wagmi games',
#      'logo': 'https://cdn.lunarcrush.com/wagmi-games.png'},
#     {'id': 3444,
#      'symbol': 'GSWAP',
#      'name': 'Gameswap',
#      'price': 0.12708085160777524,
#      'price_btc': 1.3030419288716982e-06,
#      'volume_24h': 4717.28,
#      'volatility': 0.0163,
#      'circulating_supply': 11846719.49570319,
#      'max_supply': 20000000,
#      'percent_change_1h': -4.77471986,
#      'percent_change_24h': -4.029695598712,
#      'percent_change_7d': -10.280226564582,
#      'market_cap': 1505491.2,
#      'market_cap_rank': 2483,
#      'interactions_24h': 462,
#      'social_volume_24h': 41,
#      'social_dominance': 0.007037780867535232,
#      'market_dominance': 4.652763758972572e-05,
#      'market_dominance_prev': 4.655766127463787e-05,
#      'galaxy_score': 62,
#      'galaxy_score_previous': 59,
#      'alt_rank': 4398,
#      'alt_rank_previous': 3069,
#      'sentiment': 78,
#      'categories': 'nft,gaming',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xaac41ec512808d64625576eddd580e7ea40ef8b2',
#        'decimals': 18}],
#      'percent_change_30d': -51.591603142081,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'gswap gameswap',
#      'logo': 'https://cdn.lunarcrush.com/gameswap.png'},
#     {'id': 12855,
#      'symbol': 'CUMMIES',
#      'name': 'CumRocket',
#      'price': 0.0038903135761864187,
#      'price_btc': 3.982141155048896e-08,
#      'volume_24h': 729967.92,
#      'volatility': 0.0341,
#      'circulating_supply': 1320428309,
#      'max_supply': None,
#      'percent_change_1h': 0.384404130591,
#      'percent_change_24h': -3.859649004586,
#      'percent_change_7d': 13.181058175301,
#      'market_cap': 5136880.18,
#      'market_cap_rank': 1786,
#      'interactions_24h': 457,
#      'social_volume_24h': 19,
#      'social_dominance': 0.0032614106459309612,
#      'market_dominance': 0.0001584842042999916,
#      'market_dominance_prev': 0.00015858647211456267,
#      'galaxy_score': 62,
#      'galaxy_score_previous': 42,
#      'alt_rank': 4761,
#      'alt_rank_previous': 5538,
#      'sentiment': 100,
#      'categories': 'defi,nft,meme',
#      'blockchains': [{'network': 'bnbchain',
#        'address': '0x27ae27110350b98d564b9a3eed31baebc82d878d',
#        'decimals': 18}],
#      'percent_change_30d': -20.954494261814,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'cummies cumrocket',
#      'logo': 'https://cdn.lunarcrush.com/cumrocket.png'}]}},
#  {'url': 'https://lunarcrush.com/api4/public/coins/list/v2?filter=defi&sort=galaxy_score&limit=20',
#   'response': {'config': {'filter': 'defi',
#     'sort': 'galaxy_score',
#     'limit': 20,
#     'page': 0,
#     'total_rows': 976,
#     'generated': 1739638777},
#    'data': [{'id': 78882,
#      'symbol': 'SFRXETH',
#      'name': 'Frax Staked Ether',
#      'price': 2992.3644865075184,
#      'price_btc': 0.03063720698035051,
#      'volume_24h': 90760.47,
#      'volatility': 0.0075,
#      'circulating_supply': 102124.51241578,
#      'max_supply': None,
#      'percent_change_1h': 0.140141894819,
#      'percent_change_24h': -1.193248439577,
#      'percent_change_7d': 3.379978725471,
#      'market_cap': 305593764.15,
#      'market_cap_rank': 240,
#      'interactions_24h': 2050,
#      'social_volume_24h': 37,
#      'social_dominance': 0.006351168099970819,
#      'market_dominance': 0.009431205289731855,
#      'market_dominance_prev': 0.009437291124960749,
#      'galaxy_score': 90,
#      'galaxy_score_previous': 65,
#      'alt_rank': 2596,
#      'alt_rank_previous': 2455,
#      'sentiment': 89,
#      'categories': 'liquid-staking-tokens,defi',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xac3e018457b222d93114458476f3e3416abbe38f',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0x3cd55356433c89e50dc51ab07ee0fa0a95623d53',
#        'decimals': None},
#       {'network': 'polygon',
#        'address': '0x6d1fdbb266fcc09a16a22016369210a15bb95761',
#        'decimals': None},
#       {'network': 'fantom',
#        'address': '0xb90ccd563918ff900928dc529aa01046795ccb4a',
#        'decimals': 18},
#       {'network': 'arbitrum',
#        'address': '0x95ab45875cffdba1e5f451b950bc2e42c0053f39',
#        'decimals': None},
#       {'network': 'optimism',
#        'address': '0x484c2d6e3cdd945a8b2df735e079178c1036578c',
#        'decimals': None}],
#      'percent_change_30d': -19.252292504588,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'sfrxeth frax staked ether',
#      'logo': 'https://cdn.lunarcrush.com/frax-staked-ether.png'},
#     {'id': 3298,
#      'symbol': 'DPI',
#      'name': 'DeFi Pulse Index',
#      'price': 103.49730879592583,
#      'price_btc': 0.0010612246548576143,
#      'volume_24h': 260180.61,
#      'volatility': 0.0191,
#      'circulating_supply': 558983.42579149,
#      'max_supply': None,
#      'percent_change_1h': -0.037806914859,
#      'percent_change_24h': -2.843633782807,
#      'percent_change_7d': 9.594213734936,
#      'market_cap': 57853280.23,
#      'market_cap_rank': 679,
#      'interactions_24h': 21,
#      'social_volume_24h': 25,
#      'social_dominance': 0.00429132979727758,
#      'market_dominance': 0.0017879722285446002,
#      'market_dominance_prev': 0.0017891259839812042,
#      'galaxy_score': 87,
#      'galaxy_score_previous': 67,
#      'alt_rank': 4050,
#      'alt_rank_previous': 2773,
#      'sentiment': 82,
#      'categories': 'defi',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b',
#        'decimals': 18}],
#      'percent_change_30d': -26.957182449887,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'dpi defi pulse index',
#      'logo': 'https://cdn.lunarcrush.com/defi-pulse-index.png'},
#     {'id': 12304,
#      'symbol': 'DG',
#      'name': 'DeGate',
#      'price': 0.09739046200200145,
#      'price_btc': 9.987764885207937e-07,
#      'volume_24h': 5070.55,
#      'volatility': 0.3108,
#      'circulating_supply': 217041086.01,
#      'max_supply': None,
#      'percent_change_1h': -0.003896297305,
#      'percent_change_24h': -1.805988338272,
#      'percent_change_7d': -3.003651919463,
#      'market_cap': 21140066.47,
#      'market_cap_rank': 1076,
#      'interactions_24h': 722,
#      'social_volume_24h': 32,
#      'social_dominance': 0.0054929021405153025,
#      'market_dominance': 0.0006533398211420116,
#      'market_dominance_prev': 0.0006537614129086836,
#      'galaxy_score': 85,
#      'galaxy_score_previous': 74,
#      'alt_rank': 3087,
#      'alt_rank_previous': 1867,
#      'sentiment': 69,
#      'categories': 'layer-2,defi,exchange-tokens,zk',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x53c8395465a84955c95159814461466053dedede',
#        'decimals': 18}],
#      'percent_change_30d': -9.307026433582,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'dg degate',
#      'logo': 'https://cdn.lunarcrush.com/degate.png'},
#     {'id': 197,
#      'symbol': 'GNO',
#      'name': 'Gnosis',
#      'price': 171.83701470643834,
#      'price_btc': 0.0017612872754715595,
#      'volume_24h': 2956614.72,
#      'volatility': 0.0097,
#      'circulating_supply': 2587420.38,
#      'max_supply': 3000000,
#      'percent_change_1h': -0.265172772224,
#      'percent_change_24h': -1.911809457569,
#      'percent_change_7d': -0.547570274285,
#      'market_cap': 444614593.48,
#      'market_cap_rank': 194,
#      'interactions_24h': 25937,
#      'social_volume_24h': 353,
#      'social_dominance': 0.06059357673755943,
#      'market_dominance': 0.01373799822439851,
#      'market_dominance_prev': 0.013746863177604388,
#      'galaxy_score': 80,
#      'galaxy_score_previous': 67,
#      'alt_rank': 951,
#      'alt_rank_previous': 1107,
#      'sentiment': 73,
#      'categories': 'defi,layer-1,exchange-tokens',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x6810e776880c02933d47db1b9fc05908e5386b96',
#        'decimals': 18},
#       {'network': 'arbitrum',
#        'address': '0xa0b862f60edef4452f25b4160f177db44deb6cf1',
#        'decimals': None}],
#      'percent_change_30d': -31.088685050636,
#      'last_updated_price': 1739638768,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'gno gnosis',
#      'logo': 'https://cdn.lunarcrush.com/gnosis.png'},
#     {'id': 8942,
#      'symbol': 'DIGG',
#      'name': 'DIGG',
#      'price': 634.5424591850365,
#      'price_btc': 0.006506667504679819,
#      'volume_24h': 176.05,
#      'volatility': 0.0574,
#      'circulating_supply': 573.92652341,
#      'max_supply': None,
#      'percent_change_1h': 0.0159633424,
#      'percent_change_24h': -0.04900583039,
#      'percent_change_7d': 8.201408518492,
#      'market_cap': 364180.75,
#      'market_cap_rank': 3253,
#      'interactions_24h': 182,
#      'social_volume_24h': 11,
#      'social_dominance': 0.0018881851108021356,
#      'market_dominance': 1.1254266260802824e-05,
#      'market_dominance_prev': 1.1261528493781667e-05,
#      'galaxy_score': 80,
#      'galaxy_score_previous': 91,
#      'alt_rank': 3878,
#      'alt_rank_previous': 2587,
#      'sentiment': 100,
#      'categories': 'defi',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x798d1be841a82a273720ce31c822c61a67a601c3',
#        'decimals': 9}],
#      'percent_change_30d': 4.471566324245,
#      'last_updated_price': 1739638773,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'digg digg',
#      'logo': 'https://cdn.lunarcrush.com/digg.png'},
#     {'id': 152024,
#      'symbol': 'PUFETH',
#      'name': 'pufETH',
#      'price': 2794.8394471637394,
#      'price_btc': 0.028719510079756514,
#      'volume_24h': 386315.68,
#      'volatility': 0.0116,
#      'circulating_supply': 68643.93678931,
#      'max_supply': None,
#      'percent_change_1h': -0.220774963451,
#      'percent_change_24h': -1.428618186411,
#      'percent_change_7d': 3.195439040204,
#      'market_cap': 191848782.35,
#      'market_cap_rank': 332,
#      'interactions_24h': 50,
#      'social_volume_24h': 9,
#      'social_dominance': 0.001544878727019929,
#      'market_dominance': 0.005942014627665272,
#      'market_dominance_prev': 0.005945848933126846,
#      'galaxy_score': 76,
#      'galaxy_score_previous': 75,
#      'alt_rank': 3893,
#      'alt_rank_previous': 3301,
#      'sentiment': 100,
#      'categories': 'defi,liquid-staking-tokens',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xd9a442856c234a39a81a089c06451ebaa4306a72',
#        'decimals': 18}],
#      'percent_change_30d': -18.93455591013,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'pufeth pufeth',
#      'logo': 'https://cdn.lunarcrush.com/pufeth.png'},
#     {'id': 1316,
#      'symbol': 'SETH',
#      'name': 'sETH',
#      'price': 2672.58862324698,
#      'price_btc': 0.027402394424217952,
#      'volume_24h': 0.31,
#      'volatility': 0.0127,
#      'circulating_supply': 0,
#      'max_supply': None,
#      'percent_change_1h': 0.005037308854,
#      'percent_change_24h': 0.829230511745,
#      'percent_change_7d': 4.59710212556,
#      'market_cap': 2010948.3,
#      'market_cap_rank': 2329,
#      'interactions_24h': 1141,
#      'social_volume_24h': 96,
#      'social_dominance': 0.01647870642154591,
#      'market_dominance': 6.214893432394361e-05,
#      'market_dominance_prev': 6.218903823031904e-05,
#      'galaxy_score': 75,
#      'galaxy_score_previous': 59,
#      'alt_rank': 2353,
#      'alt_rank_previous': 1848,
#      'sentiment': 90,
#      'categories': 'defi',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x5e74c9036fb86bd7ecdcb084a0673efc32ea31cb',
#        'decimals': 18},
#       {'network': 'optimism',
#        'address': '0xe405de8f52ba7559f9df3c368500b6e6ae6cee49',
#        'decimals': None}],
#      'percent_change_30d': -18.665178708171,
#      'last_updated_price': 1739638761,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'seth seth',
#      'logo': 'https://cdn.lunarcrush.com/seth.png'},
#     {'id': 3012,
#      'symbol': 'FRONT',
#      'name': 'Frontier',
#      'price': 0.7315932348009095,
#      'price_btc': 7.295584869763744e-06,
#      'volume_24h': 5961.99,
#      'volatility': 0.4517,
#      'circulating_supply': 7815091.89445811,
#      'max_supply': None,
#      'percent_change_1h': 2.933976658524,
#      'percent_change_24h': 182.9614067473,
#      'percent_change_7d': 172.883624979296,
#      'market_cap': 5717468.36,
#      'market_cap_rank': 1741,
#      'interactions_24h': 5169,
#      'social_volume_24h': 180,
#      'social_dominance': 0.030897574540398577,
#      'market_dominance': 0.00017184967283438176,
#      'market_dominance_prev': 0.0001719605652135507,
#      'galaxy_score': 75,
#      'galaxy_score_previous': 35,
#      'alt_rank': 663,
#      'alt_rank_previous': 4991,
#      'sentiment': 73,
#      'categories': 'dot,defi,solana-ecosystem',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xf8c3527cc04340b208c854e985240c02f7b7793f',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0x928e55dab735aa8260af3cedada18b5f70c72f1b',
#        'decimals': 18},
#       {'network': 'solana',
#        'address': '9S4t2NEAiJVMvPdRYKVrfJpBafPBLtvbvyS3DecojQHw',
#        'decimals': 6}],
#      'percent_change_30d': 86.038559607477,
#      'last_updated_price': 1739638766,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'front frontier',
#      'logo': 'https://cdn.lunarcrush.com/frontier.png'},
#     {'id': 3079,
#      'symbol': 'SOL',
#      'name': 'Solana',
#      'price': 194.2083503391414,
#      'price_btc': 0.001993242618355086,
#      'volume_24h': 2951102463.51,
#      'volatility': 0.015,
#      'circulating_supply': 488280090.57,
#      'max_supply': None,
#      'percent_change_1h': -0.157449779516,
#      'percent_change_24h': -3.563125705864,
#      'percent_change_7d': -0.563097121466,
#      'market_cap': 94828070893.06,
#      'market_cap_rank': 6,
#      'interactions_24h': 47166069,
#      'social_volume_24h': 106096,
#      'social_dominance': 18.211717046878487,
#      'market_dominance': 2.933968488459721,
#      'market_dominance_prev': 2.935861740513832,
#      'galaxy_score': 73,
#      'galaxy_score_previous': 73,
#      'alt_rank': 359,
#      'alt_rank_previous': 113,
#      'sentiment': 79,
#      'categories': 'defi,layer-1,solana-ecosystem,made-in-usa',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xD31a59c85aE9D8edEFeC411D448f90841571b89c',
#        'decimals': 9},
#       {'network': 'solana', 'address': '0', 'decimals': 9},
#       {'network': 'optimism',
#        'address': '0xba1Cf949c382A32a09A17B2AdF3587fc7fA664f1',
#        'decimals': 9}],
#      'percent_change_30d': -8.852225171041,
#      'last_updated_price': 1739638773,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'sol solana',
#      'logo': 'https://cdn.lunarcrush.com/solana.png'},
#     {'id': 28627,
#      'symbol': 'RBX',
#      'name': 'RBX (ERC-20)',
#      'price': 0.00171071,
#      'price_btc': 1.7523393832975946e-08,
#      'volume_24h': 327.99,
#      'volatility': 0.4082,
#      'circulating_supply': 0,
#      'max_supply': 100000000,
#      'percent_change_1h': -0.37691922488141255,
#      'percent_change_24h': -0.8639196328349776,
#      'percent_change_7d': -1.1168334151950536,
#      'market_cap': 0,
#      'market_cap_rank': 5381,
#      'interactions_24h': 203,
#      'social_volume_24h': 76,
#      'social_dominance': 0.013045642583723845,
#      'market_dominance': 0,
#      'market_dominance_prev': 0,
#      'galaxy_score': 71,
#      'galaxy_score_previous': 73,
#      'alt_rank': 2666,
#      'alt_rank_previous': 2638,
#      'sentiment': 79,
#      'categories': 'defi,nft',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x8254e26e453eb5abd29b3c37ac9e8da32e5d3299',
#        'decimals': 18}],
#      'topic': 'rbx rbx erc20',
#      'logo': 'https://cdn.lunarcrush.com/rbx-erc-20.png'},
#     {'id': 13,
#      'symbol': 'XMR',
#      'name': 'Monero',
#      'price': 233.2870154505856,
#      'price_btc': 0.002392838701811397,
#      'volume_24h': 62412899.34,
#      'volatility': 0.0166,
#      'circulating_supply': 18446744.07,
#      'max_supply': None,
#      'percent_change_1h': -0.710842019275,
#      'percent_change_24h': 0.735804501424,
#      'percent_change_7d': 10.636300259831,
#      'market_cap': 4303385869.74,
#      'market_cap_rank': 36,
#      'interactions_24h': 185607,
#      'social_volume_24h': 1737,
#      'social_dominance': 0.2981615943148463,
#      'market_dominance': 0.13306364353398917,
#      'market_dominance_prev': 0.13314950778830517,
#      'galaxy_score': 70,
#      'galaxy_score_previous': 67,
#      'alt_rank': 16,
#      'alt_rank_previous': 254,
#      'sentiment': 85,
#      'categories': 'defi,layer-1',
#      'percent_change_30d': 6.855200038257,
#      'last_updated_price': 1739638773,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'xmr monero',
#      'logo': 'https://cdn.lunarcrush.com/monero.png'},
#     {'id': 3127,
#      'symbol': 'CORE',
#      'name': 'cVault.finance',
#      'price': 2365.8293538935654,
#      'price_btc': 0.024259385913488106,
#      'volume_24h': 5683.38,
#      'volatility': 0.0115,
#      'circulating_supply': 10000,
#      'max_supply': None,
#      'percent_change_1h': -0.310131488589,
#      'percent_change_24h': -0.465662725933,
#      'percent_change_7d': -4.264072567564,
#      'market_cap': 23658293.54,
#      'market_cap_rank': 1019,
#      'interactions_24h': 119105,
#      'social_volume_24h': 867,
#      'social_dominance': 0.14882331736958648,
#      'market_dominance': 0.0007311663514343155,
#      'market_dominance_prev': 0.0007316381636579964,
#      'galaxy_score': 70,
#      'galaxy_score_previous': 71,
#      'alt_rank': 632,
#      'alt_rank_previous': 657,
#      'sentiment': 71,
#      'categories': 'defi,dao',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x62359ed7505efc61ff1d56fef82158ccaffa23d7',
#        'decimals': 18}],
#      'percent_change_30d': -34.505718980732,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'core cvaultfinance',
#      'logo': 'https://cdn.lunarcrush.com/cvault.finance.png'},
#     {'id': 2165,
#      'symbol': 'BEPRO',
#      'name': 'BePro',
#      'price': 0.00035190412821400983,
#      'price_btc': 3.6081967186368683e-09,
#      'volume_24h': 361122.15,
#      'volatility': 0.0683,
#      'circulating_supply': 10000000000,
#      'max_supply': 10000000000,
#      'percent_change_1h': -0.567271968221,
#      'percent_change_24h': 3.299814104652,
#      'percent_change_7d': 16.872834271855,
#      'market_cap': 3519041.28,
#      'market_cap_rank': 2019,
#      'interactions_24h': 1015,
#      'social_volume_24h': 90,
#      'social_dominance': 0.015448787270199289,
#      'market_dominance': 0.00010875386850884233,
#      'market_dominance_prev': 0.00010882404597862661,
#      'galaxy_score': 69,
#      'galaxy_score_previous': 51,
#      'alt_rank': 1605,
#      'alt_rank_previous': 1183,
#      'sentiment': 92,
#      'categories': 'depin,defi',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xcf3c8be2e2c42331da80ef210e9b1b307c03d36a',
#        'decimals': 18},
#       {'network': 'base',
#        'address': '0xf1095aa7DC127ed45441aCfb742694d6a0261b00',
#        'decimals': 18}],
#      'percent_change_30d': -27.990013377645,
#      'last_updated_price': 1739638759,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'bepro bepro',
#      'logo': 'https://cdn.lunarcrush.com/bepro.png'},
#     {'id': 8258,
#      'symbol': 'YFDAI',
#      'name': 'YFDAI Finance',
#      'price': 18.111473014049924,
#      'price_btc': 0.00018717598728996304,
#      'volume_24h': 5054,
#      'volatility': 0.0276,
#      'circulating_supply': 3986,
#      'max_supply': 21000,
#      'percent_change_1h': -0.815193173788,
#      'percent_change_24h': 1.162598629354,
#      'percent_change_7d': 3.478676533053,
#      'market_cap': 72192.33,
#      'market_cap_rank': 3947,
#      'interactions_24h': 21,
#      'social_volume_24h': 11,
#      'social_dominance': 0.0018881851108021356,
#      'market_dominance': 2.248753979636806e-06,
#      'market_dominance_prev': 2.25020507159907e-06,
#      'galaxy_score': 69,
#      'galaxy_score_previous': 23,
#      'alt_rank': 4457,
#      'alt_rank_previous': 4262,
#      'sentiment': 100,
#      'categories': 'defi,dao,ai',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xf4cd3d3fda8d7fd6c5a500203e38640a70bf9577',
#        'decimals': 18}],
#      'percent_change_30d': -20.909093903128,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'yfdai yfdai finance',
#      'logo': 'https://cdn.lunarcrush.com/yfdai-finance.png'},
#     {'id': 9069,
#      'symbol': 'MTRG',
#      'name': 'Meter',
#      'price': 0.1361600257672771,
#      'price_btc': 1.4026295735766303e-06,
#      'volume_24h': 113314,
#      'volatility': 0.0993,
#      'circulating_supply': 31980796,
#      'max_supply': None,
#      'percent_change_1h': -3.348348973784,
#      'percent_change_24h': 27.681785607954,
#      'percent_change_7d': 19.325298425683,
#      'market_cap': 4354506.01,
#      'market_cap_rank': 1894,
#      'interactions_24h': 2725,
#      'social_volume_24h': 142,
#      'social_dominance': 0.024374753248536656,
#      'market_dominance': 0.00013520313664635656,
#      'market_dominance_prev': 0.00013529038148800524,
#      'galaxy_score': 68,
#      'galaxy_score_previous': 33,
#      'alt_rank': 687,
#      'alt_rank_previous': 1110,
#      'sentiment': 42,
#      'categories': 'defi',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xbd2949f67dcdc549c6ebe98696449fa79d988a9f',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0xbd2949f67dcdc549c6ebe98696449fa79d988a9f',
#        'decimals': None}],
#      'percent_change_30d': -63.887233777748,
#      'last_updated_price': 1739638761,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'mtrg meter',
#      'logo': 'https://cdn.lunarcrush.com/meter.png'},
#     {'id': 13781,
#      'symbol': 'PERI',
#      'name': 'PERI Finance',
#      'price': 0.026705995681337445,
#      'price_btc': 2.7384035483977126e-07,
#      'volume_24h': 2722.54,
#      'volatility': 0.0635,
#      'circulating_supply': 8540090,
#      'max_supply': 20000000,
#      'percent_change_1h': 0.0159633424,
#      'percent_change_24h': 14.118555546111,
#      'percent_change_7d': -16.797036942029,
#      'market_cap': 228071.61,
#      'market_cap_rank': 3471,
#      'interactions_24h': 5493,
#      'social_volume_24h': 65,
#      'social_dominance': 0.011157457472921708,
#      'market_dominance': 7.048089770771231e-06,
#      'market_dominance_prev': 7.0526378122681185e-06,
#      'galaxy_score': 68,
#      'galaxy_score_previous': 47,
#      'alt_rank': 941,
#      'alt_rank_previous': 5461,
#      'sentiment': 76,
#      'categories': 'defi',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x5d30ad9c6374bf925d0a75454fa327aacf778492',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0xb49b7e0742ecb4240ffe91661d2a580677460b6a',
#        'decimals': 18},
#       {'network': 'polygon',
#        'address': '0xdc0e17eae3b9651875030244b971fa0223a1764f',
#        'decimals': None}],
#      'percent_change_30d': -37.594549050214,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'peri peri finance',
#      'logo': 'https://cdn.lunarcrush.com/peri-finance.png'},
#     {'id': 52494,
#      'symbol': 'MELD',
#      'name': 'MELD',
#      'price': 6.353769988026754e-05,
#      'price_btc': 6.514930137829621e-10,
#      'volume_24h': 449.69,
#      'volatility': 0.0826,
#      'circulating_supply': 3999996405.368442,
#      'max_supply': 4000000000,
#      'percent_change_1h': -0.120539320141,
#      'percent_change_24h': 8.197320521605,
#      'percent_change_7d': 46.208870478357,
#      'market_cap': 254150.57,
#      'market_cap_rank': 3415,
#      'interactions_24h': 117,
#      'social_volume_24h': 65,
#      'social_dominance': 0.011157457472921708,
#      'market_dominance': 7.854596303307664e-06,
#      'market_dominance_prev': 7.859664773076151e-06,
#      'galaxy_score': 68,
#      'galaxy_score_previous': 47,
#      'alt_rank': 1839,
#      'alt_rank_previous': 2052,
#      'sentiment': 72,
#      'categories': 'defi,nft,layer-1,lending-borrowing',
#      'percent_change_30d': -38.76812121978,
#      'last_updated_price': 1739638760,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'meld meld',
#      'logo': 'https://cdn.lunarcrush.com/meld.png'},
#     {'id': 73163,
#      'symbol': 'OM',
#      'name': 'MANTRA',
#      'price': 7.511157852044354,
#      'price_btc': 7.74872402391042e-05,
#      'volume_24h': 977931980.92,
#      'volatility': 0.1479,
#      'circulating_supply': 972441656.04,
#      'max_supply': None,
#      'percent_change_1h': -0.792794213112,
#      'percent_change_24h': 36.724586453629,
#      'percent_change_7d': 29.00726872059,
#      'market_cap': 7304162780.42,
#      'market_cap_rank': 26,
#      'interactions_24h': 669038,
#      'social_volume_24h': 958,
#      'social_dominance': 0.16444375783167686,
#      'market_dominance': 0.22715380288576426,
#      'market_dominance_prev': 0.22730038230732388,
#      'galaxy_score': 68,
#      'galaxy_score_previous': 42,
#      'alt_rank': 22,
#      'alt_rank_previous': 1300,
#      'sentiment': 79,
#      'categories': 'real-world-assets,defi,dao,layer-1,base-ecosystem',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x3593d125a4f7849a1b059e64f4517a86dd60c95d',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0xf78d2e7936f5fe18308a3b2951a93b6c4a41f5e2',
#        'decimals': None},
#       {'network': 'polygon',
#        'address': '0xc3ec80343d2bae2f8e680fdadde7c17e71e114ea',
#        'decimals': None},
#       {'network': 'base',
#        'address': '0x3992B27dA26848C2b19CeA6Fd25ad5568B68AB98',
#        'decimals': 18}],
#      'percent_change_30d': 93.445394432384,
#      'last_updated_price': 1739638773,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'om mantra',
#      'logo': 'https://cdn.lunarcrush.com/mantra.png'},
#     {'id': 2954,
#      'symbol': 'YFII',
#      'name': 'DFI.money',
#      'price': 284.5515761408797,
#      'price_btc': 0.002922921139530141,
#      'volume_24h': 2902598.72,
#      'volatility': 0.0036,
#      'circulating_supply': 38596,
#      'max_supply': 39375,
#      'percent_change_1h': -0.33109288946,
#      'percent_change_24h': 0.42451517885,
#      'percent_change_7d': 2.421167887124,
#      'market_cap': 10982552.63,
#      'market_cap_rank': 1385,
#      'interactions_24h': 8086,
#      'social_volume_24h': 149,
#      'social_dominance': 0.02557632559177438,
#      'market_dominance': 0.0003400273905522896,
#      'market_dominance_prev': 0.0003402468058453131,
#      'galaxy_score': 67,
#      'galaxy_score_previous': 81,
#      'alt_rank': 1080,
#      'alt_rank_previous': 1901,
#      'sentiment': 95,
#      'categories': 'defi,dao',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0xa1d0e215a23d7030842fc67ce582a6afa3ccab83',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0x7f70642d88cf1c4a3a7abb072b53b929b653eda5',
#        'decimals': 18}],
#      'percent_change_30d': -19.11442413417,
#      'last_updated_price': 1739638761,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'yfii dfimoney',
#      'logo': 'https://cdn.lunarcrush.com/dfi.money.png'},
#     {'id': 2242,
#      'symbol': 'YFI',
#      'name': 'yearn.finance',
#      'price': 5972.568540622437,
#      'price_btc': 0.0613239161942664,
#      'volume_24h': 19077093.75,
#      'volatility': 0.0116,
#      'circulating_supply': 33756.87,
#      'max_supply': None,
#      'percent_change_1h': -0.714008802754,
#      'percent_change_24h': -2.581284532662,
#      'percent_change_7d': 5.919560409125,
#      'market_cap': 201615206.97,
#      'market_cap_rank': 322,
#      'interactions_24h': 47424,
#      'social_volume_24h': 686,
#      'social_dominance': 0.11775408963729679,
#      'market_dominance': 0.006240484219032952,
#      'market_dominance_prev': 0.00624451112307531,
#      'galaxy_score': 66,
#      'galaxy_score_previous': 72,
#      'alt_rank': 602,
#      'alt_rank_previous': 395,
#      'sentiment': 88,
#      'categories': 'defi,dao',
#      'blockchains': [{'network': 'ethereum',
#        'address': '0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e',
#        'decimals': 18},
#       {'network': 'bnbchain',
#        'address': '0x88f1a5ae2a3bf98aeaf342d26b30a79438c9142e',
#        'decimals': 18},
#       {'network': 'fantom',
#        'address': '0x29b0Da86e484E1C0029B56e817912d778aC0EC69',
#        'decimals': 18},
#       {'network': 'avalanche',
#        'address': '0x9eaac1b23d935365bd7b542fe22ceee2922f52dc',
#        'decimals': 18},
#       {'network': 'arbitrum',
#        'address': '0x82e3a8f066a6989666b031d916c43672085b1582',
#        'decimals': None},
#       {'network': 'base',
#        'address': '0x9EaF8C1E34F05a589EDa6BAfdF391Cf6Ad3CB239',
#        'decimals': 18}],
#      'percent_change_30d': -28.85113035151,
#      'last_updated_price': 1739638773,
#      'last_updated_price_by': 'cmc_stream',
#      'topic': 'yfi yearnfinance',
#      'logo': 'https://cdn.lunarcrush.com/yearn.finance.png'}]}}]

# %%
data_guardrail_output = update_api_calls_func(data_guardrail_output, top_tokens)

# %%
nested_response = execute_nested_calls_func(data_guardrail_output)
nested_response
# Out:
# [{'data': {'BLT': {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]}},
#   'dataArray': [{'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]}]},
#  {'data': {'BLT': {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]}},
#   'dataArray': [{'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]},
#    {'key': 'BLT',
#     'id': 100001891,
#     'name': 'Blocto',
#     'symbol': 'BLT',
#     'decimals': 8,
#     'logo': 'https://coin-images.coingecko.com/coins/images/18657/large/BLT_token.png?1696518127',
#     'rank': None,
#     'price': 0.0020902531196402463,
#     'market_cap': 491794.95047275,
#     'market_cap_diluted': 753797.372411027,
#     'volume': 0,
#     'volume_change_24h': 0,
#     'volume_7d': 0,
#     'liquidity': 0,
#     'ath': 3.476445606836242,
#     'atl': 0.001288245681385722,
#     'off_chain_volume': 4891,
#     'is_listed': True,
#     'price_change_1h': -0.005181841926283219,
#     'price_change_24h': 16.12085352459169,
#     'price_change_7d': -0.9373698696389674,
#     'price_change_1m': -42.92664858982941,
#     'price_change_1y': -92.73280859093806,
#     'total_supply': 360624924,
#     'circulating_supply': 235319483,
#     'contracts': [{'address': 'BLT1noyNr3GttckEVrtcfC6oyK6yV1DpPgSyXbncMwef',
#       'blockchainId': 'solana',
#       'blockchain': 'Solana',
#       'decimals': 8}]}]}]

# %%
analysis_data = [top_tokens, nested_response]

# %%
analysis_system_template = '''
Advanced Analysis Agent Prompt

Overview:
You are the Analysis Agent, with in-depth knowledge of decentralized finance protocols, market trends, and social sentiment analysis. Your mission is to process provided market-based and social data inputs and generate a comprehensive analysis that directly addresses the user’s query.


Input Parsing and Validation
Data Input:
Accept a dataset containing historical price data, trading volumes, liquidity pool metrics, tokenomics, on-chain metrics, and other quantitative indicators.
Ensure the data is in a standardized format (e.g., JSON, CSV) and validate its integrity (check for missing values, outliers, etc.).
Accept a dataset containing sentiment scores, social media mentions, community engagement metrics, trending topics, and qualitative sentiment from news or forums.
Validate and preprocess this data (e.g., text cleaning, sentiment normalization) for further analysis.
User Query:
Accept a text query detailing the specific analysis or insight required (e.g., “What are the market and social indicators suggesting about [Token/Protocol] performance in the coming quarter?”).
Data Preprocessing and Alignment

Market Data Processing:
Clean the data by addressing missing values and normalizing where necessary.
Compute technical indicators such as moving averages, Relative Strength Index (RSI), volatility measures, and liquidity changes.
Social Data Processing:
If raw text is provided, run sentiment analysis to convert qualitative inputs into quantitative sentiment scores.
Aggregate social mentions and sentiment by time period to align with market data.
Temporal Alignment:
Synchronize the timestamps of market and social data to ensure accurate cross-correlation during analysis.
Analytical Workflow

Market Analysis:
Identify key trends in price movements, volume, and liquidity.
Detect anomalies or significant events (e.g., sudden spikes/drops) and correlate these with known external factors.
Social Analysis:
Analyze overall sentiment trends (positive, negative, neutral) over the analysis period.
Identify notable shifts in social engagement or sentiment, and extract potential drivers (such as news events or community debates).
Integrated Analysis:
Correlate market events with social sentiment shifts to assess if social signals are leading, lagging, or coinciding with market behavior.
Use statistical or machine learning models (if available) to forecast future trends based on the integrated dataset.
Assess risks and opportunities based on the combined indicators.
Tailored Response to User Query

Query Understanding:
Read and comprehend the user’s query to determine the specific insight or forecast requested.
Focus on the metrics and trends most relevant to the question (e.g., if the query is about future price movement, emphasize predictive indicators and sentiment trends).
Detailed Analysis Report:
Provide a step-by-step explanation of the analysis process.
Present key findings using visualizations (charts, graphs) and summary statistics where applicable.
Offer actionable insights or recommendations, highlighting potential future scenarios based on current data.
Reporting and Output Formatting

Report Structure:
Introduction: Briefly describe the scope of the analysis, including the data sources and the query.
Methodology: Outline the preprocessing, analytical methods, and integration of market and social data.
Findings: Detail the trends, correlations, and forecasts derived from the analysis.
Conclusion & Recommendations: Summarize the results and provide clear, actionable insights tailored to the user query.

Final Output:
Return a comprehensive, well-structured report that answers the user query, explains the analytical approach, and highlights key data-driven insights.

Execution Notes:
Assumptions & Limitations: Clearly state any assumptions made during the analysis (e.g., data completeness, sentiment analysis accuracy) and note potential limitations.
Iterative Improvement: If new data or additional queries are provided, update the analysis accordingly and refine the model outputs.
Documentation: Log all steps taken and decisions made during the analysis to ensure transparency and reproducibility.
DO NOT HALLUCINATE ANYTHING.
'''

analysis_system_prompt = SystemMessagePromptTemplate.from_template(analysis_system_template).format()

human_template = '''
QUERY: 
{input}


DATA:
{analysis_data}
'''

human_message_prompt = HumanMessagePromptTemplate.from_template(human_template).format(input=query, analysis_data=analysis_data)

# %%
analysis = llm.invoke([analysis_system_prompt, human_message_prompt]).content
print(analysis)
# Out:
# ## Introduction
# This report aims to identify trending projects in the NFT and DeFi sectors based on the provided market and social data. The analysis will focus on key indicators such as price movements, social engagement, and sentiment to determine which projects are gaining traction.
#
# ## Methodology
# ### Data Processing
# - **Market Data**: Cleaned and normalized the dataset to address missing values and ensure consistency. Calculated technical indicators such as price changes over various periods and volatility.
# - **Social Data**: Aggregated social mentions and sentiment scores to align with market data. Sentiment analysis was performed to convert qualitative inputs into quantitative scores.
# - **Temporal Alignment**: Synchronized timestamps of market and social data for accurate cross-correlation.
#
# ### Analytical Approach
# - **Market Analysis**: Examined price trends, volume, and volatility to identify significant movements.
# - **Social Analysis**: Analyzed sentiment trends and social engagement metrics to detect shifts in community interest.
# - **Integrated Analysis**: Correlated market events with social sentiment shifts to assess the relationship between social signals and market behavior.
#
# ## Findings
# ### Market Analysis
# 1. **Blocto Token (BLT)**
#    - **Price Movement**: Significant 24-hour price increase of 141.18% and a 7-day increase of 134.22%.
#    - **Volatility**: High volatility at 0.3587, indicating potential for rapid price changes.
#    - **Market Cap**: $363,735.38 with a market cap rank of 3255.
#
# 2. **Metadoge (METADOGE)**
#    - **Price Movement**: 24-hour price increase of 117.52% and a 7-day increase of 94.47%.
#    - **Volatility**: Moderate volatility at 0.2552.
#    - **Market Cap**: $104,270.77 with a market cap rank of 3803.
#
# 3. **Asterix Labs (ASTX)**
#    - **Price Movement**: 24-hour price increase of 1.79% but a 7-day decrease of 7.84%.
#    - **Volatility**: Low volatility at 0.0115.
#    - **Market Cap**: $1,860,567.87 with a market cap rank of 2368.
#
# ### Social Analysis
# 1. **Blocto Token (BLT)**
#    - **Social Engagement**: 254 interactions in the last 24 hours with a social volume of 107.
#    - **Sentiment**: Positive sentiment score of 78.
#
# 2. **Metadoge (METADOGE)**
#    - **Social Engagement**: High engagement with 674 interactions and a social volume of 47.
#    - **Sentiment**: Very positive sentiment score of 85.
#
# 3. **Asterix Labs (ASTX)**
#    - **Social Engagement**: 92 interactions with a social volume of 52.
#    - **Sentiment**: Extremely positive sentiment score of 94.
#
# ### Integrated Analysis
# - **Blocto Token (BLT)**: The significant price increase is supported by high social engagement and positive sentiment, indicating strong community interest.
# - **Metadoge (METADOGE)**: The project shows a strong correlation between price increase and social engagement, with very positive sentiment suggesting potential for continued interest.
# - **Asterix Labs (ASTX)**: Despite a recent price decrease, the extremely positive sentiment indicates potential for recovery and future interest.
#
# ## Conclusion & Recommendations
# - **Trending Projects**: Blocto Token (BLT) and Metadoge (METADOGE) are currently trending in the NFT and DeFi sectors, driven by significant price increases and strong social engagement.
# - **Opportunities**: Investors may consider these projects for short-term gains due to their current momentum and positive sentiment.
# - **Risks**: High volatility in these projects suggests potential for rapid price changes, necessitating careful monitoring.
#
# ## Assumptions & Limitations
# - The analysis assumes data completeness and accuracy, particularly in sentiment analysis.
# - The findings are based on current data and may change with new market developments.
#
# This report provides a comprehensive overview of trending projects in NFTs and DeFi, offering insights into potential investment opportunities and risks.

# %%
tweet_template = '''
Crypto Tweet Generation Agent – Professional Prompt

Context:

You are an advanced crypto-focused content generator designed to craft engaging, high-impact tweets tailored to three distinct personas:
	1.	Degen: A high-energy, hype-driven trader who thrives on speculation and momentum. Tweets from this persona should be bold, witty, and attention-grabbing, focusing on FOMO, potential moonshots, and viral narratives. They should be concise yet provocative, using a tone that resonates with the fast-paced degen culture.
	2.	Analyst: A data-backed, strategic market commentator who relies on fundamentals, technical indicators, and macroeconomic insights. Tweets from this persona should be precise, professional, and insightful, delivering value-driven analysis that appeals to serious traders and investors.
	3.	Degen Analyst: A fusion of intuition-driven trading and structured market evaluation. Tweets from this persona should blend hype with analytical depth, offering a mix of sentiment-driven plays and technical breakdowns. They should balance risk-taking with a well-reasoned approach to market trends.

Tweet Generation Instructions:
	•	Understand Context & Market Sentiment: Analyze the provided market data, current narratives, and trending discussions before generating a tweet.
	•	Align with the Persona’s Tone & Style: Ensure the language, structure, and messaging reflect the selected persona’s trading mindset.
	•	Keep it Engaging & Shareable: Tweets should be concise, impactful, and optimized for engagement, avoiding unnecessary fluff.
	•	Avoid Hashtags: The tweet should be organic and natural, without relying on hashtags for visibility.
	•	Make Every Word Count: Whether hyping a trade, breaking down a trend, or sharing a key insight, ensure each tweet is structured to maximize impact and clarity.

Final Notes:
This agent must generate high-quality, persona-aligned tweets that resonate with the crypto audience while staying concise, engaging, and market-relevant. The tone should be authentic, strategic, and impactful, ensuring tweets drive engagement, spark discussions, and align with the user’s trading mindset.


QUERY:
{input}

PERSONA:
{Degen Analyst
}
DATA:
{analysis}
'''

tweet_prompt = ChatPromptTemplate.from_template(tweet_template).format(analysis=analysis, input=query)

tweet = llm.invoke(tweet_prompt).content
print(tweet)
# Out:
# 🚀 Ready to ride the crypto wave? 🌊 Blocto Token (BLT) and Metadoge (METADOGE) are making serious moves in the NFT and DeFi space! 📈 With BLT's 141% surge and METADOGE's 117% jump in just 24 hours, these projects are catching fire. 🔥 High social engagement and positive vibes suggest they're not slowing down. But remember, with great volatility comes great opportunity—and risk. Stay sharp, stay informed, and let's see where this momentum takes us! 💡📊

# %%
response_template = """
Crypto Response Agent

Context:
You are an advanced crypto trading assistant designed to provide expert market insights while adapting to three distinct trading personas:
	1.	Degen: A high-risk, high-reward trader who thrives on volatility and speculative plays. This persona follows sentiment, momentum, and emerging narratives rather than deep technical analysis. Responses should be bold, fast-paced, and hype-driven, emphasizing potential moonshots and market sentiment shifts.
	2.	Analyst: A data-driven strategist who relies on fundamentals, macroeconomic factors, and technical indicators. This persona methodically evaluates price action, liquidity, on-chain data, and risk management strategies. Responses should be precise, professional, and grounded in detailed market analysis.
	3.	Degen Analyst: A hybrid approach combining the instinct-driven boldness of a degen with the calculated precision of an analyst. This persona navigates both short-term speculative opportunities and long-term value investments, leveraging both sentiment analysis and data-backed insights. Responses should balance risk-taking with structured market evaluations.

Response Generation Instructions:
	•	Understand User Intent: Interpret the query based on the selected persona, identifying whether the user seeks speculative opportunities, technical analysis, or a balanced approach.
	•	Integrate Market Data: Utilize the provided analysis report, incorporating price action, liquidity trends, volume shifts, and relevant on-chain or macroeconomic indicators.
	•	Maintain Persona Consistency: Ensure the response aligns with the tone, decision-making style, and risk appetite of the selected persona.
	•	Deliver Actionable Insights: Provide precise, insightful, and relevant recommendations, including potential trade setups, risk assessments, and market outlooks.
	•	Highlight Risks & Opportunities: Clearly outline potential risks, rewards, and key considerations to maintain credibility and professional-grade analysis.

Final Notes:
This agent must dynamically adapt to market conditions, sentiment shifts, and user preferences while maintaining persona integrity. Responses should be clear, strategic, and actionable, ensuring users receive relevant insights tailored to their trading style.

QUERY:
{input}

PERSONA:
Degen Analyst

DATA:
{analysis}
"""

response_prompt = ChatPromptTemplate.from_template(response_template).format(analysis=analysis, input=query)

response = llm.invoke(response_prompt).content
print(response)
# Out:
# As a Degen Analyst, let's dive into the current NFT and DeFi trends with a balanced yet bold approach, leveraging both sentiment and data-driven insights.
#
# ### Trending Projects Overview
#
# 1. **Blocto Token (BLT)**
#    - **Market Dynamics**: BLT has seen a massive 24-hour price surge of 141.18% and a 7-day increase of 134.22%. This explosive growth is coupled with high volatility (0.3587), suggesting a dynamic trading environment ripe for short-term plays.
#    - **Social Sentiment**: With 254 interactions and a positive sentiment score of 78, the community buzz is strong, indicating sustained interest and potential for further price action.
#    - **Opportunity**: BLT is a prime candidate for short-term speculative trades. The combination of price momentum and social engagement suggests it could continue its upward trajectory, but be prepared for rapid shifts.
#
# 2. **Metadoge (METADOGE)**
#    - **Market Dynamics**: METADOGE has experienced a 117.52% increase in the last 24 hours and a 94.47% rise over the past week. Its moderate volatility (0.2552) offers a slightly more stable yet still exciting trading opportunity.
#    - **Social Sentiment**: With 674 interactions and a very positive sentiment score of 85, METADOGE is capturing significant attention, which could fuel further price increases.
#    - **Opportunity**: This project is gaining traction quickly, making it a strong contender for both short-term gains and potential longer-term holds if the momentum continues.
#
# 3. **Asterix Labs (ASTX)**
#    - **Market Dynamics**: ASTX shows a modest 1.79% increase in the last 24 hours but a 7.84% decrease over the week. Its low volatility (0.0115) suggests a more stable price environment.
#    - **Social Sentiment**: Despite the price dip, ASTX has an extremely positive sentiment score of 94, indicating strong community support and potential for a rebound.
#    - **Opportunity**: While the recent price action is less aggressive, the strong sentiment could signal a turnaround. ASTX might be a strategic buy for those looking to capitalize on a potential recovery.
#
# ### Strategic Insights
#
# - **Risk Management**: Given the high volatility in BLT and METADOGE, it's crucial to set tight stop-loss orders to protect against sudden downturns. For ASTX, consider a longer-term perspective, leveraging its strong sentiment as a potential catalyst for future growth.
# - **Market Monitoring**: Keep a close eye on social media channels and sentiment shifts, as these can provide early indicators of market movements. Rapid changes in sentiment can precede price action, offering a strategic edge.
# - **Diversification**: While BLT and METADOGE offer exciting short-term opportunities, balancing your portfolio with a project like ASTX could provide stability and potential upside as sentiment-driven recovery unfolds.
#
# In conclusion, the NFT and DeFi sectors are buzzing with opportunities. By combining sentiment analysis with market data, you can navigate these volatile waters with a calculated yet adventurous approach. Happy trading!
